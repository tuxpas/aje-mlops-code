# %% [markdown]
# # 1 Descargar Ventas y Visitas (aje-prd-analytics-artifacts-s3)

# %%
#!pip install 'awswrangler[redshift]'
#!pip install psycopg2-binary


# !pip install --upgrade pip setuptools wheel
# !pip install --upgrade pyarrow==17.0.0
# !pip install "awswrangler[redshift]" --no-build-isolation
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (26.0.1)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (82.0.1)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (0.46.3)
# Requirement already satisfied: packaging>=24.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from wheel) (24.2)
# Requirement already satisfied: pyarrow==17.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (17.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from pyarrow==17.0.0) (1.26.4)
# Requirement already satisfied: awswrangler[redshift] in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (3.15.1)
# Requirement already satisfied: boto3<2,>=1.20.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from awswrangler[redshift]) (1.42.69)
# Requirement already satisfied: botocore<2,>=1.23.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from awswrangler[redshift]) (1.42.69)
# Requirement already satisfied: numpy<3.0,>=1.26 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from awswrangler[redshift]) (1.26.4)
# Requirement already satisfied: packaging<27.0,>=21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from awswrangler[redshift]) (24.2)
# Requirement already satisfied: pandas<3.0.0,>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from awswrangler[redshift]) (2.3.3)
# Requirement already satisfied: pyarrow<23.0.0,>=8.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from awswrangler[redshift]) (17.0.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from awswrangler[redshift]) (82.0.1)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from awswrangler[redshift]) (4.15.0)
# Requirement already satisfied: redshift-connector<3,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from awswrangler[redshift]) (2.1.12)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from boto3<2,>=1.20.32->awswrangler[redshift]) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from boto3<2,>=1.20.32->awswrangler[redshift]) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from botocore<2,>=1.23.32->awswrangler[redshift]) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from botocore<2,>=1.23.32->awswrangler[redshift]) (2.6.3)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from pandas<3.0.0,>=1.2.0->awswrangler[redshift]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from pandas<3.0.0,>=1.2.0->awswrangler[redshift]) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2,>=1.23.32->awswrangler[redshift]) (1.17.0)
# Requirement already satisfied: scramp<1.5.0,>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from redshift-connector<3,>=2.0.0->awswrangler[redshift]) (1.4.8)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from redshift-connector<3,>=2.0.0->awswrangler[redshift]) (4.14.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from redshift-connector<3,>=2.0.0->awswrangler[redshift]) (2.32.5)
# Requirement already satisfied: lxml<6.0.0,>=4.6.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from redshift-connector<3,>=2.0.0->awswrangler[redshift]) (5.4.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.7.0->redshift-connector<3,>=2.0.0->awswrangler[redshift]) (2.8.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->redshift-connector<3,>=2.0.0->awswrangler[redshift]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->redshift-connector<3,>=2.0.0->awswrangler[redshift]) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.23.0->redshift-connector<3,>=2.0.0->awswrangler[redshift]) (2026.1.4)
# Requirement already satisfied: asn1crypto>=1.5.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (from scramp<1.5.0,>=1.2.0->redshift-connector<3,>=2.0.0->awswrangler[redshift]) (1.5.1)
# Requirement already satisfied: psycopg2-binary in /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages (2.9.11)

# %%
# import psutil
# import time
# import threading
# import matplotlib.pyplot as plt

# # Variables globales
# mem_usage_gb = []
# mem_usage_percent = []
# cpu_usage_gb = []
# cpu_usage_percent = []
# timestamps = []
# running = True  # Variable de control

# # Función de monitoreo en segundo plano
# def monitor_resources():
#     global running
#     start_time = time.time()
    
#     while running:
#         # Obtener información del sistema
#         mem_info = psutil.virtual_memory()
#         cpu_percent = psutil.cpu_percent(interval=0.5)  # Medir CPU sin bloquear
#         cpu_used_gb = (cpu_percent / 100) * (psutil.virtual_memory().total / (1024**3))  # Estimación del uso de CPU en GB
        
#         # Guardar datos
#         timestamp = time.time() - start_time
#         mem_usage_gb.append(mem_info.used / (1024 ** 3))  # RAM usada en GB
#         mem_usage_percent.append(mem_info.percent)  # RAM en %
#         cpu_usage_gb.append(cpu_used_gb)  # CPU en GB
#         cpu_usage_percent.append(cpu_percent)  # CPU en %
#         timestamps.append(timestamp)
        
#         # Imprimir valores en tiempo real
#         # print(f"Tiempo: {timestamp:.2f}s | RAM: {mem_info.percent:.2f}% ({mem_usage_gb[-1]:.2f} GB) | CPU: {cpu_percent:.2f}% ({cpu_used_gb:.2f} GB)")
        
#         time.sleep(1)  # Medir cada 1 segundo

# # Iniciar monitoreo en segundo plano
# monitor_thread = threading.Thread(target=monitor_resources, daemon=True)
# monitor_thread.start()

# print("Monitoreo de CPU y RAM iniciado en segundo plano...")

# %%
import pandas as pd
import numpy as np
import redshift_connector
import awswrangler as wr
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import os
import boto3
import io
import pytz
import re
import gc

# %%
def comprobar_inputs():
    # Conectarse a S3
    s3 = boto3.client("s3")
    bucket_name = "aje-prd-analytics-artifacts-s3"
    prefix = "pedido_sugerido/data-v1/ecuador/"
    
    hoy = datetime.now(pytz.timezone("America/Lima")).date()
    errores = []

    # Listar objetos en la ruta de S3
    objetos = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

    if "Contents" not in objetos:
        print("ERROR: No se encontraron archivos en la ruta especificada.")
        return

    # Iterar sobre los objetos
    for objeto in objetos["Contents"]:
        key = objeto["Key"]
        print(key)
        # Omitir "carpetas" en S3
        if key.endswith("/"):
            continue

        last_modified = objeto["LastModified"].date()
        size_kb = objeto["Size"] / 1024  # Convertir a KB

        # Verificar si el objeto tiene contenido real (FULL_OBJECT)
        if objeto["Size"] == 0:
            errores.append(f"ERROR: El archivo {key} está vacío.")

        # Verificar si el archivo ha sido modificado hoy
        if last_modified != hoy:
            errores.append(f"ERROR: El archivo {key} no ha sido modificado hoy ({hoy}), su ultima fecha de modificacion fue {last_modified}.")

        # Verificar si el tamaño del archivo es menor a 1 KB
        if size_kb < 1:
            errores.append(f"ALERTA: El archivo {key} tiene un tamaño menor a 1 KB ({size_kb:.2f} KB).")

    # Mostrar los errores y lanzar una excepción si es necesario
    if errores:
        for error in errores:
            print(error)
        raise ValueError("Se encontraron problemas con los archivos en S3.")
    else:
        print("Todo bien :D")

# %%
comprobar_inputs()
# Out:
# pedido_sugerido/data-v1/ecuador/
# pedido_sugerido/data-v1/ecuador/D_stock_ec.csv
# pedido_sugerido/data-v1/ecuador/EC_maestro_productos.csv
# pedido_sugerido/data-v1/ecuador/maestro_productos_ecuador000
# pedido_sugerido/data-v1/ecuador/ventas_ecuador000
# pedido_sugerido/data-v1/ecuador/ventas_ecuador_tomorrow.csv
# pedido_sugerido/data-v1/ecuador/visitas_ecuador000
# Todo bien :D

# %% [markdown]
# ## 1.0 Descargar Maestro de productos

# %%
# PARA 2024
query = f"""select * from 
    comercial_ecuador.dim_producto
    where estado='A' and instancia='EC';
    """

con = wr.data_api.redshift.connect(
    cluster_id="dwh-cloud-storage-salesforce-prod",
    database="dwh_prod",
    db_user="dwhuser",
)
maestro_prod = wr.data_api.rds.read_sql_query(query, con)

# %%
maestro_prod.head()
# Out:
#      id_producto instancia                                      desc_compania  \
# 0  EC|0030|60968        EC  AJEMEX                                        ...
# 1  EC|0030|60969        EC  AJEMEX                                        ...
# 2  EC|0030|60970        EC  AJEMEX                                        ...
# 3  EC|0030|60971        EC  AJEMEX                                        ...
# 4  EC|0030|60972        EC  AJEMEX                                        ...
#
#    cod_articulo_magic                            desc_articulo  \
# 0               60968   PREFORMA DE 17.15 GRS CRISTAL  AGUA PT
# 1               60969  PREFORMA DE 17.15 GRS CRISTAL CON UV PT
# 2               60970         PREFORMA DE 17.15 GRS CRISTAL PT
# 3               60971            PREFORMA DE 17.15 GRS AZUL PT
# 4               60972      PREFORMA DE 17.15 GRS AZUL  AGUA PT
#
#               desc_articulo_corto cod_linea  \
# 0   PREFORMA DE 17.15 GRS CRISTAL        01
# 1   PREFORMA DE 17.15 GRS CRISTAL        01
# 2   PREFORMA DE 17.15 GRS CRISTAL        01
# 3   PREFORMA DE 17.15 GRS AZUL PT        01
# 4  PREFORMA DE 17.15 GRS AZUL  AG        01
#
#                                  desc_linea cod_familia  \
# 0  PRODUCTO TERMINADO                               015
# 1  PRODUCTO TERMINADO                               015
# 2  PRODUCTO TERMINADO                               015
# 3  PRODUCTO TERMINADO                               015
# 4  PRODUCTO TERMINADO                               015
#
#                                desc_familia  ... flg_tipo_composicion  \
# 0  PREFORMAS                                 ...                    C
# 1  PREFORMAS                                 ...                    C
# 2  PREFORMAS                                 ...                    C
# 3  PREFORMAS                                 ...                    C
# 4  PREFORMAS                                 ...                    C
#
#   flg_linea paquete flg_preventa flgabastec flgskuplan flg_explosion  \
# 0        Te       1            N         OP          N             N
# 1        Te       1            N         OP          N             N
# 2        Te       1            N         OP          N             N
# 3        Te       1            N         OP          N             N
# 4        Te       1            N         OP          N             N
#
#   fecha_creacion cod_unidad_negocio desc_unidad_negocio
# 0     2015-06-05                                   None
# 1     2015-06-05                                   None
# 2     2015-06-05                                   None
# 3     2015-06-05                                   None
# 4     2015-06-05                                   None
#
# [5 rows x 51 columns]

# %%
maestro_prod.groupby(["cod_articulo_magic", "desc_articulo"]).head(1)[["cod_articulo_magic", "desc_articulo"]].to_csv("Input/EC_maestro_productos.csv", index=False)

# %%
# Fecha de hoy
hoy = datetime.today()

# Fecha de hace 12 meses
hace_12_meses = hoy - timedelta(days=365)

# Formato año-mes-dia
fecha_i = hoy.strftime("%Y-%m-%d")
fecha_f = hace_12_meses.strftime("%Y-%m-%d")
print(fecha_i, fecha_f)
# Out:
# 2026-03-30 2025-03-30

# %%
# 1403, 5617, 1304, # Piloto
rutas_test = [1008,1108,1208,1308,1408,1608,2808,1708,1808, # Ambato
              1908,2008,2108,2208,2408,
              1003,1103,1203,1303,1403,1503,1603,1703,4403, # Guayaquil norte
              1803,1903,2003,2103,2203,2303,2403,2503,2603,
              2703,2803,2903,3003,3103,3203,3303,3403,4703,
              4903,5203,5603,5703,
              1017,1117,1217,1317,1417,1517,1617,1717,1817, # Guayaquil Sur
              1917,2017,2117,2217,2317,2417,2517,2617,2717,
              2817,2917,3017,3117,3217,3317,3417,3517,3617,
              3717,3817,3917,4017,4117,4217,4317,4417,4517,
              4617,4717,4817,4917,5517,5617,5717,
              1006,1106,1206,1306,1406,1506,1606,1706,1806, # Machala
              1906,2006,2106,2206,2306,3806,4106,2406,2506,
              2606,2706,2806,2906,3006,3106,
              1007,1307,1507,1807,1907,2007,2107,2307,2407, # Manta
              2507,2607,2707,2807,3607,1107,1207,1407,1607,
              2207,3507,3707,3307,3107,
              1004,1104,1204,1304,1404,1504,1604,1704,1804, # Quito norte
              1904,2004,2104,2204,2304,2404,2504,2604,2704,
              2804,2904,3004,3104,3204,3304,3404,3504,3604,
              4504,4604,4704,4804,4904,5104,5204,5404,
              1011,1211,1311,1411,1611,1711,1811,1911,1511, # Quito sur
              2011,2111,2211,2511,2711,2811,4711,2311,2411,
              2611,2911,3411,3511,3611,3911,3011,3111,3211,
              3311,3711,3811,4011,4811,
              1009,1209,1609,1909,2009,2609,2709,2809,1109, # Santo Domingo
              1309,1409,1709,1809,2109,2209]
              
print(rutas_test)
# Out:
# [1008, 1108, 1208, 1308, 1408, 1608, 2808, 1708, 1808, 1908, 2008, 2108, 2208, 2408, 1003, 1103, 1203, 1303, 1403, 1503, 1603, 1703, 4403, 1803, 1903, 2003, 2103, 2203, 2303, 2403, 2503, 2603, 2703, 2803, 2903, 3003, 3103, 3203, 3303, 3403, 4703, 4903, 5203, 5603, 5703, 1017, 1117, 1217, 1317, 1417, 1517, 1617, 1717, 1817, 1917, 2017, 2117, 2217, 2317, 2417, 2517, 2617, 2717, 2817, 2917, 3017, 3117, 3217, 3317, 3417, 3517, 3617, 3717, 3817, 3917, 4017, 4117, 4217, 4317, 4417, 4517, 4617, 4717, 4817, 4917, 5517, 5617, 5717, 1006, 1106, 1206, 1306, 1406, 1506, 1606, 1706, 1806, 1906, 2006, 2106, 2206, 2306, 3806, 4106, 2406, 2506, 2606, 2706, 2806, 2906, 3006, 3106, 1007, 1307, 1507, 1807, 1907, 2007, 2107, 2307, 2407, 2507, 2607, 2707, 2807, 3607, 1107, 1207, 1407, 1607, 2207, 3507, 3707, 3307, 3107, 1004, 1104, 1204, 1304, 1404, 1504, 1604, 1704, 1804, 1904, 2004, 2104, 2204, 2304, 2404, 2504, 2604, 2704, 2804, 2904, 3004, 3104, 3204, 3304, 3404, 3504, 3604, 4504, 4604, 4704, 4804, 4904, 5104, 5204, 5404, 1011, 1211, 1311, 1411, 1611, 1711, 1811, 1911, 1511, 2011, 2111, 2211, 2511, 2711, 2811, 4711, 2311, 2411, 2611, 2911, 3411, 3511, 3611, 3911, 3011, 3111, 3211, 3311, 3711, 3811, 4011, 4811, 1009, 1209, 1609, 1909, 2009, 2609, 2709, 2809, 1109, 1309, 1409, 1709, 1809, 2109, 2209]

# %%
len(rutas_test)
# Out:
# 217

# %%
clientes_ruta_test = []

# %%
def descargar_visitas():
    # Guardar clientes de las rutas
    global clientes_ruta_test

    # Conectarse a S3
    s3 = boto3.client("s3")
    bucket_name = "aje-prd-analytics-artifacts-s3"
    prefix = "pedido_sugerido/data-v1/ecuador/"

    # Listar objetos en la ruta de S3
    objetos = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

    print(objetos)

    # Iterar sobre los objetos
    for objeto in objetos["Contents"]:
        if objeto["Size"] > 0 and objeto["Key"].split("/")[-1] == "visitas_ecuador000":
            # Obtener el nombre del objeto y descargarlo
            nombre_archivo = objeto["Key"].split("/")[-1]

            # Descargar el archivo en memoria
            response = s3.get_object(Bucket=bucket_name, Key=objeto["Key"])
            content = response["Body"].read()

            # Filtrar y guardar el archivo si corresponde
            if nombre_archivo == "visitas_ecuador000":
                # Convertir los bytes a DataFrame de Pandas
                df = pd.read_csv(io.BytesIO(content), sep=";")
                df = df[
                    # (df["compania__c"] == 90)
                    # & (df["cod_ruta"].isin(rutas_test))
                    (df["cod_ruta"].isin(rutas_test))
                    # & (df.codigo_canal__c == 2)
                ].reset_index(drop=True)
                # Guardamos estos clientes para descargarlos en ventas (por si cambiaron de ruta)
                clientes_ruta_test = df["codigo_cliente__c"].unique()
                nombre_csv = f"Input/{nombre_archivo}.parquet"
                df["personalizacion"] = df["personalizacion"].astype(str)
                df.to_parquet(nombre_csv, index=False)
            else:
                continue

# %%
# %%time
descargar_visitas()
# Out:
# {'ResponseMetadata': {'RequestId': 'VQ9GC29T7XEF9V36', 'HostId': 'TUm4TBIEe1DzA+d83c26hTcCI8T7opqRkEJ7cyFdUSsrunZgNi0N62YHHMgDoMq/F556s/a2fn55E1ty7UN7ikn4Ub1iLPb9', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'TUm4TBIEe1DzA+d83c26hTcCI8T7opqRkEJ7cyFdUSsrunZgNi0N62YHHMgDoMq/F556s/a2fn55E1ty7UN7ikn4Ub1iLPb9', 'x-amz-request-id': 'VQ9GC29T7XEF9V36', 'date': 'Mon, 30 Mar 2026 20:23:18 GMT', 'x-amz-bucket-region': 'us-east-2', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'IsTruncated': False, 'Contents': [{'Key': 'pedido_sugerido/data-v1/ecuador/', 'LastModified': datetime.datetime(2024, 2, 8, 8, 32, 4, tzinfo=tzlocal()), 'ETag': '"d41d8cd98f00b204e9800998ecf8427e"', 'Size': 0, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/D_stock_ec.csv', 'LastModified': datetime.datetime(2026, 3, 30, 14, 3, 33, tzinfo=tzlocal()), 'ETag': '"3735f313af8a36807f4ef593c3d9a675"', 'ChecksumAlgorithm': ['CRC32'], 'ChecksumType': 'FULL_OBJECT', 'Size': 107911, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/EC_maestro_productos.csv', 'LastModified': datetime.datetime(2026, 3, 30, 17, 58, 36, tzinfo=tzlocal()), 'ETag': '"0d29f7a783d0b2b396e31d4c104d8eae"', 'ChecksumAlgorithm': ['CRC32'], 'ChecksumType': 'FULL_OBJECT', 'Size': 424139, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/maestro_productos_ecuador000', 'LastModified': datetime.datetime(2026, 3, 30, 16, 23, 24, tzinfo=tzlocal()), 'ETag': '"4dcb1fd8ff29a4a18b636110c02c56f0-5"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 276683991, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/ventas_ecuador000', 'LastModified': datetime.datetime(2026, 3, 30, 16, 21, 38, tzinfo=tzlocal()), 'ETag': '"67ce594c1d0a67dd5f0d4b66d31c5095-69"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 4629077890, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/ventas_ecuador_tomorrow.csv', 'LastModified': datetime.datetime(2026, 3, 30, 17, 58, 36, tzinfo=tzlocal()), 'ETag': '"8f28f52afeaec8e7bccea4af579945e8-102"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 533814035, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/visitas_ecuador000', 'LastModified': datetime.datetime(2026, 3, 30, 16, 10, 57, tzinfo=tzlocal()), 'ETag': '"b2afc31800c045c18811121f5afd6881-1"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 19305210, 'StorageClass': 'STANDARD'}], 'Name': 'aje-prd-analytics-artifacts-s3', 'Prefix': 'pedido_sugerido/data-v1/ecuador/', 'MaxKeys': 1000, 'EncodingType': 'url', 'KeyCount': 7}
# CPU times: user 439 ms, sys: 102 ms, total: 541 ms
# Wall time: 764 ms

# %%
def descargar_ventas():
    # Conectarse a S3
    s3 = boto3.client("s3")
    bucket_name = "aje-prd-analytics-artifacts-s3"
    prefix = "pedido_sugerido/data-v1/ecuador/"

    # Listar objetos en la ruta de S3
    objetos = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

    print(objetos)
    
    final_csv = pd.DataFrame()

    # Iterar sobre los objetos
    for objeto in objetos["Contents"]:
        if objeto["Size"] > 0 and objeto["Key"].split("/")[-1] != "visitas_ecuador000":
            # Obtener el nombre del objeto y descargarlo
            nombre_archivo = objeto["Key"].split("/")[-1]

            # Filtrar y guardar el archivo si corresponde
            if nombre_archivo == "ventas_ecuador000":
                # Descargar el archivo en memoria
                response = s3.get_object(Bucket=bucket_name, Key=objeto["Key"])
                content = response["Body"].read()
                # Convertir los bytes a DataFrame de Pandas
                df = pd.read_csv(io.BytesIO(content), sep=";")
                df = df[
                    (df["cod_compania"] == 90)
                    & (
                        (df["cod_ruta"].isin(rutas_test))
                        | (df["cod_cliente"].isin(clientes_ruta_test))
                    )
                ].reset_index(drop=True)[['id_cliente', 'id_sucursal', 'id_producto',
       'fecha_liquidacion',"cod_ruta","cod_modulo",
       'cod_zona', 'cant_cajafisicavta', 'cant_cajaunitvta','imp_netovta',
       'cod_compania', 'desc_compania', 'cod_sucursal',
       'desc_sucursal', 'cod_pais', 'fecha_creacion_cliente', 'cod_cliente',
       'desc_marca', 'desc_formato', 'desc_categoria', 'cod_giro',
       'cod_subgiro', 'desc_giro', 'desc_subgiro', 'fecha_proceso']]
                final_csv = pd.concat([final_csv, df], ignore_index=True)
            elif nombre_archivo == "ventas_ecuador001":
                # # Descargar el archivo en memori
                # response = s3.get_object(Bucket=bucket_name, Key=objeto["Key"])
                # content = response["Body"].read()
                # # Convertir los bytes a DataFrame de Pandas
                # df = pd.read_csv(io.BytesIO(content), sep=";")
                # df = df[
                #     (df["cod_compania"] == 90)
                #     & (
                #         (df["cod_ruta"].isin(rutas_test))
                #         | (df["cod_cliente"].isin(clientes_ruta_test))
                #     )
                # ].reset_index(drop=True)
                # final_csv = pd.concat([final_csv, df], ignore_index=True)
                continue
            else:
                continue

    nombre_csv = f"Input/ventas_ec_all.parquet"
    final_csv.to_parquet(nombre_csv, index=False)

# %%
# %%time
descargar_ventas()
# Out:
# {'ResponseMetadata': {'RequestId': 'QAD9TK3R6AHKD1NQ', 'HostId': '9nfB5EqWomViPV5gQDVrMx73WvIL/WN6+DhoR1SbsVUICpHO1ZYQn+FVbujCdfZnCOIH1AkZ0eAH7oM+tcYf9nV+u5VilKz8', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': '9nfB5EqWomViPV5gQDVrMx73WvIL/WN6+DhoR1SbsVUICpHO1ZYQn+FVbujCdfZnCOIH1AkZ0eAH7oM+tcYf9nV+u5VilKz8', 'x-amz-request-id': 'QAD9TK3R6AHKD1NQ', 'date': 'Mon, 30 Mar 2026 20:23:19 GMT', 'x-amz-bucket-region': 'us-east-2', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'IsTruncated': False, 'Contents': [{'Key': 'pedido_sugerido/data-v1/ecuador/', 'LastModified': datetime.datetime(2024, 2, 8, 8, 32, 4, tzinfo=tzlocal()), 'ETag': '"d41d8cd98f00b204e9800998ecf8427e"', 'Size': 0, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/D_stock_ec.csv', 'LastModified': datetime.datetime(2026, 3, 30, 14, 3, 33, tzinfo=tzlocal()), 'ETag': '"3735f313af8a36807f4ef593c3d9a675"', 'ChecksumAlgorithm': ['CRC32'], 'ChecksumType': 'FULL_OBJECT', 'Size': 107911, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/EC_maestro_productos.csv', 'LastModified': datetime.datetime(2026, 3, 30, 17, 58, 36, tzinfo=tzlocal()), 'ETag': '"0d29f7a783d0b2b396e31d4c104d8eae"', 'ChecksumAlgorithm': ['CRC32'], 'ChecksumType': 'FULL_OBJECT', 'Size': 424139, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/maestro_productos_ecuador000', 'LastModified': datetime.datetime(2026, 3, 30, 16, 23, 24, tzinfo=tzlocal()), 'ETag': '"4dcb1fd8ff29a4a18b636110c02c56f0-5"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 276683991, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/ventas_ecuador000', 'LastModified': datetime.datetime(2026, 3, 30, 16, 21, 38, tzinfo=tzlocal()), 'ETag': '"67ce594c1d0a67dd5f0d4b66d31c5095-69"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 4629077890, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/ventas_ecuador_tomorrow.csv', 'LastModified': datetime.datetime(2026, 3, 30, 17, 58, 36, tzinfo=tzlocal()), 'ETag': '"8f28f52afeaec8e7bccea4af579945e8-102"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 533814035, 'StorageClass': 'STANDARD'}, {'Key': 'pedido_sugerido/data-v1/ecuador/visitas_ecuador000', 'LastModified': datetime.datetime(2026, 3, 30, 16, 10, 57, tzinfo=tzlocal()), 'ETag': '"b2afc31800c045c18811121f5afd6881-1"', 'ChecksumAlgorithm': ['CRC64NVME'], 'ChecksumType': 'FULL_OBJECT', 'Size': 19305210, 'StorageClass': 'STANDARD'}], 'Name': 'aje-prd-analytics-artifacts-s3', 'Prefix': 'pedido_sugerido/data-v1/ecuador/', 'MaxKeys': 1000, 'EncodingType': 'url', 'KeyCount': 7}
# CPU times: user 1min 25s, sys: 16.9 s, total: 1min 42s
# Wall time: 2min 22s

# %% [markdown]
# ## 1.1 Juntar VENTAS y VISITAS

# %%
pan_ventas = pd.read_parquet("Input/ventas_ec_all.parquet")
pan_visitas = pd.read_parquet("Input/visitas_ecuador000.parquet")

# %%
pan_visitas = pan_visitas[(pan_visitas.codigo_canal__c==2)&(pan_visitas.compania__c=="0090")].reset_index(drop=True)

# %%
pan_ventas["cod_articulo_magic"] = pan_ventas["id_producto"].str.split("|").str[-1]
pan_ventas["cod_articulo_magic"] = pan_ventas["cod_articulo_magic"].astype(int)

# %%
pan_ventas.shape
# Out:
# (10579712, 26)

# %%
# Nos quedamos solo con las filas del proceso de hoy
# Obtener la fecha de hoy en el mismo formato
hoy = int(datetime.now(pytz.timezone("America/Lima")).strftime('%Y%m%d'))
print(hoy)
# Filtrar solo las filas con la fecha de hoy
pan_ventas = pan_ventas[pan_ventas['fecha_proceso'] == hoy]
# Out:
# 20260330

# %%
pan_ventas.shape
# Out:
# (10579712, 26)

# %%
# Obtener la fecha y año actual
current_date = datetime.now(pytz.timezone("America/Lima"))
# Formatear la fecha en el formato "YYYYMM"
formatted_date = current_date.strftime("%Y-%m-%d")
formatted_date
# Out:
# '2026-03-30'

# %%
# Establecer la conexión con S3
bucket_name = 'aje-analytics-ps-backup'  # nombre de bucket en S3
file_name = f'PS_Ecuador/Input/visitas_ecuador000_{formatted_date}.csv'  # nombre para el archivo en S3
s3_path = f's3://{bucket_name}/{file_name}'

# Escribir el dataframe en S3 con AWS Data Wrangler
wr.s3.to_csv(pan_visitas, s3_path, index=False)
# Out:
# {'paths': ['s3://aje-analytics-ps-backup/PS_Ecuador/Input/visitas_ecuador000_2026-03-30.csv'],
#  'partitions_values': {}}

# %%
#pan_ventas[["cod_compania","cod_articulo_magic","cod_portafolio_producto"]].drop_duplicates().sort_values("cod_articulo_magic").reset_index(drop=True).to_excel("D_PS_EC_compania_producto_portafolio.xlsx")

# %%
# PAN VENTAS
pan_ventas["cod_compania"] = (
    pan_ventas["cod_compania"].astype(str).apply(lambda x: str(int(x)).rjust(4, "0"))
)
pan_ventas["id_cliente"] = (
    "EC"
    + "|"
    + pan_ventas["cod_compania"].astype(str)
    + "|"
    + pan_ventas["cod_cliente"].astype(str)
)

# PAN VISITAS
pan_visitas["compania__c"] = (
    pan_visitas["compania__c"].astype(str).apply(lambda x: str(int(x)).rjust(4, "0"))
)
pan_visitas["id_cliente"] = (
    "EC"
    + "|"
    + pan_visitas["compania__c"].astype(str)
    + "|"
    + pan_visitas["codigo_cliente__c"].astype(str)
)

# %%
# Eliminar Duplicados y quedarse con la ultima visita más reciente
visita_default_semana_atras = (datetime.now(pytz.timezone("America/Lima")) - timedelta(days=7)).strftime("%Y-%m-%d")
pan_visitas["ultima_visita"] = pan_visitas["ultima_visita"].fillna(
    visita_default_semana_atras
)
pan_visitas = (
    pan_visitas.sort_values(["id_cliente", "ultima_visita"], ascending=False)
    .groupby("id_cliente")
    .head(1)
)

# %%
# Combina ventas y visitas (nos quedamos con ruta y módulo de visitas si es nulo, usamos el valor de ventas)
df_merged = pd.merge(
    pan_ventas,
    pan_visitas[
        [
            "id_cliente",
            "dias_de_visita__c",
            "periodo_de_visita__c",
            "ultima_visita",
            "cod_ruta",
            "cod_modulo",
            "eje_potencial__c",
        ]
    ],
    on="id_cliente",
    # how='outer',  # Este es un merge 'outer', para conservar todos los clientes de ambos DataFrames.
    how="inner",
    suffixes=(
        "_df1",
        "_df2",
    ),  # Añadimos sufijos para diferenciar las columnas que se solapan
)

# Reemplazar los valores nulos de 'cod_ruta_df2' con los valores de 'cod_ruta_df1', y viceversa
# Si 'cod_ruta_df2' es nulo, se usará el valor de 'cod_ruta_df1'. Si ambos son nulos, se mantendrá nulo.
df_merged["cod_ruta"] = df_merged["cod_ruta_df2"].combine_first(
    df_merged["cod_ruta_df1"]
)
df_merged["cod_modulo"] = df_merged["cod_modulo_df2"].combine_first(
    df_merged["cod_modulo_df1"]
)

# Eliminar las columnas innecesarias ('cod_ruta_df1', 'cod_ruta_df2', 'cod_modulo_df1', 'cod_modulo_df2')
df_merged = df_merged.drop(
    columns=["cod_ruta_df1", "cod_ruta_df2", "cod_modulo_df1", "cod_modulo_df2"]
)

# %%
pan_ventas = df_merged.copy()
# Liberar memoria del df_merged
df_merged = None 
gc.collect()
# Out:
# 1565

# %%
pan_ventas["cod_cliente"] = pan_ventas["cod_cliente"].astype(str)
pan_ventas["cod_ruta"] = pan_ventas["cod_ruta"].astype(int)
pan_ventas["cod_modulo"] = pan_ventas["cod_modulo"].astype(int)

# %%
# Al cruzar visita con ventas. hay clientes de. visita que no tienen informacion de venta, esto se remplaza a nivel de ruta.
# Este df guarda clientes con visitas y sin ventas para luego recomendarlos por separado
df_clientes_con_visitas_sin_ventas = pd.DataFrame()
for ruta in pan_ventas["cod_ruta"].unique():
    temp_df = pan_ventas[pan_ventas["cod_ruta"] == ruta]
    # Si la ruta entera no tiene ninguna venta, se guarda en un dataframe aparte
    if len(temp_df) == (temp_df["cod_articulo_magic"].isnull().sum()):
        df_clientes_con_visitas_sin_ventas = pd.concat(
            [df_clientes_con_visitas_sin_ventas, temp_df], axis=0
        ).reset_index(drop=True)

# %%
pan_ventas.groupby("cod_sucursal").agg(
    {"cod_articulo_magic": "nunique", "id_cliente": "nunique", "cod_ruta": "nunique"}
)
# Out:
#               cod_articulo_magic  id_cliente  cod_ruta
# cod_sucursal
# 3                            133        7625        32
# 4                            132       10401        35
# 6                            140        6326        24
# 7                            130        5486        22
# 8                            124        3628        14
# 9                            122        4159        15
# 11                           121        8807        32
# 17                           128       10548        43

# %% [markdown]
# # 2 Ajustar DF de clientes: Se filtrará a los clientes que tienen visita al día siguiente

# %% [markdown]
# ## 2.2 Combinar Ventas con Subgiro, Descripcion de productos, Segmento del cliente y Fecha de creacion

# %%
import pandas as pd

# CAMBIAR DEPORADE POR SPORADE
pan_ventas["desc_marca"] = pan_ventas["desc_marca"].str.strip()
pan_ventas["desc_marca"] = pan_ventas["desc_marca"].replace({"DEPORADE": "SPORADE"})

pan_prod = pd.read_csv("Input/EC_maestro_productos.csv")

# Crear ID_CLIENTE
# PAN_VENTAS
pan_ventas["cod_sucursal"] = pan_ventas["cod_sucursal"].astype(str)

# PAN SEGMENTOS
pan_ventas = pan_ventas.rename(columns={"eje_potencial__c": "new_segment"})
# mapear valores
mapping = {
    "S1": "BLINDAR",
    "S2": "DESARROLLAR",
    "S4": "MANTENER",
    "S5": "OPTIMIZAR",
}

pan_ventas["new_segment"] = pan_ventas["new_segment"].map(mapping)
pan_ventas["new_segment"] = pan_ventas["new_segment"].fillna("OPTIMIZAR")

# %%
pan_ventas = pd.merge(
    pan_ventas,
    pan_prod[["cod_articulo_magic", "desc_articulo"]],
    how="left",
    on="cod_articulo_magic",
)

pan_ventas["mes"] = pd.to_datetime(pan_ventas["fecha_liquidacion"]).dt.strftime(
    "%Y-%m-01"
)

# %%
pan_ventas.to_parquet("Processed/ventas_ecuador_12m.parquet", index=False)

# %% [markdown]
# ## 2.4 Filtrar clientes a visitar mañana

# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# %%
pan_ventas = pd.read_parquet("Processed/ventas_ecuador_12m.parquet")

# %%
pan_ventas.id_cliente.nunique()
# Out:
# 56979

# %%
pan_ventas.dias_de_visita__c.unique()
# Out:
# array(['1;4', '3;6', '2;5', '2', '4', '1', '3', '5', '6', '1;2;3;4;5;6;7',
#        '1;4;5', '3;7'], dtype=object)

# %%
pan_ventas.groupby("dias_de_visita__c").id_cliente.nunique()
# Out:
# dias_de_visita__c
# 1                  294
# 1;2;3;4;5;6;7       15
# 1;4              18293
# 1;4;5                2
# 2                  261
# 2;5              18302
# 3                   88
# 3;6              19114
# 3;7                  2
# 4                  280
# 5                  227
# 6                  101
# Name: id_cliente, dtype: int64

# %%
data_test = (
    pan_ventas[
        ["id_cliente", "dias_de_visita__c", "periodo_de_visita__c", "ultima_visita"]
    ]
    .drop_duplicates()
    .reset_index(drop=True)
)
data_test["ultima_visita"] = pd.to_datetime(
    data_test["ultima_visita"], format="%Y-%m-%d"
)
# Calcula la diferencia en días entre la fecha de cada fila y la fecha de hoy
fecha_actual = datetime.now() + timedelta(days=0)
data_test["dias_pasados"] = (fecha_actual - data_test["ultima_visita"]).dt.days
fecha_actual
# Out:
# datetime.datetime(2026, 3, 30, 20, 29, 7, 897956)

# %%
# Obtener el día de la semana actual (1 para lunes, 2 para martes, ..., 7 para domingo)
dia_actual = datetime.now(pytz.timezone("America/Lima")).weekday() + 1

# Si hoy es domingo (7), el día siguiente es lunes (1), de lo contrario, es el siguiente día al actual
if dia_actual == 6:
    dia_siguiente = 7
    # dia_siguiente=6
else:
    dia_siguiente = (dia_actual + 1) % 7
    # dia_siguiente = (dia_actual ) % 7

# Filtrar los clientes que serán visitados mañana
clientes_a_visitar_manana = data_test[
    data_test["dias_de_visita__c"]
    .astype(str)
    .apply(lambda x: str(dia_siguiente) in x.split(";"))
].reset_index(drop=True)
print("dia_actual", dia_actual)
print("dia_siguiente", dia_siguiente)
# Out:
# dia_actual 1
# dia_siguiente 2

# %%
# Definir condiciones de filtro
condicion_f1 = clientes_a_visitar_manana["periodo_de_visita__c"] == "F1"
condicion_f2 = (clientes_a_visitar_manana["periodo_de_visita__c"] == "F2") & (
    clientes_a_visitar_manana["dias_pasados"] > 13
)
condicion_f3 = (clientes_a_visitar_manana["periodo_de_visita__c"] == "F3") & (
    clientes_a_visitar_manana["dias_pasados"] > 20
)
condicion_f4 = (clientes_a_visitar_manana["periodo_de_visita__c"] == "F4") & (
    clientes_a_visitar_manana["dias_pasados"] > 27
)

# Aplicar las condiciones de filtro
clientes_a_visitar_manana = clientes_a_visitar_manana[
    condicion_f1 | condicion_f2 | condicion_f3 | condicion_f4
].reset_index(drop=True)

# %%
clientes_a_visitar_manana.isnull().sum()
# Out:
# id_cliente              0
# dias_de_visita__c       0
# periodo_de_visita__c    0
# ultima_visita           0
# dias_pasados            0
# dtype: int64

# %%
clientes_a_visitar_manana.periodo_de_visita__c.unique()
# Out:
# array(['F1'], dtype=object)

# %%
clientes_a_visitar_manana.dias_de_visita__c.unique()
# Out:
# array(['2;5', '2', '1;2;3;4;5;6;7'], dtype=object)

# %%
pan_ventas.groupby("cod_ruta")["dias_de_visita__c"].unique().reset_index()
# Out:
#      cod_ruta            dias_de_visita__c
# 0        1003              [3;6, 2;5, 1;4]
# 1        1004              [3;6, 1;4, 2;5]
# 2        1006              [3;6, 1;4, 2;5]
# 3        1007  [3;6, 2;5, 1;4, 5, 2, 1, 4]
# 4        1008              [3;6, 1;4, 2;5]
# ..        ...                          ...
# 211      5517              [1;4, 3;6, 2;5]
# 212      5603              [1;4, 2;5, 3;6]
# 213      5617              [3;6, 2;5, 1;4]
# 214      5703              [1;4, 2;5, 3;6]
# 215      5717              [2;5, 3;6, 1;4]
#
# [216 rows x 2 columns]

# %%
pan_ventas = pan_ventas[
    pan_ventas["id_cliente"].isin(clientes_a_visitar_manana["id_cliente"])
].reset_index(drop=True)

# %%
pan_ventas.periodo_de_visita__c.unique()
# Out:
# array(['F1'], dtype=object)

# %%
pan_ventas.dias_de_visita__c.unique()
# Out:
# array(['2;5', '2', '1;2;3;4;5;6;7'], dtype=object)

# %%
pan_ventas.id_cliente.nunique()
# Out:
# 18578

# %%
# pan_ventas[["id_cliente", 'cod_sucursal', 'desc_sucursal','dias_de_visita__c',
#        'periodo_de_visita__c', 'ultima_visita', 'cod_ruta', 'cod_modulo']].drop_duplicates().to_csv("PS_EC_clientes_2024-10-31.csv",index=False)

# %%
pan_ventas.to_parquet("Processed/ecuador_ventas_manana.parquet", index=False)

# %% [markdown]
# # 3. Pre Procesamiento

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df_ventas = pd.read_parquet("Processed/ecuador_ventas_manana.parquet")

# %%
df_ventas["fecha_liquidacion"] = pd.to_datetime(
    df_ventas["fecha_liquidacion"], format="%Y-%m-%d"
)
df_ventas["desc_marca"] = df_ventas["desc_marca"].str.strip()
df_ventas["desc_categoria"] = df_ventas["desc_categoria"].str.strip()

# %% [markdown]
# ## 3.1 Mapeo de Pesos por Giro
# Los pesos representan el orden en el que se recomendara la marca para cada cliente dependiendo del Giro

# %%
# Mapeo de pesos para ordenar las recomendaciones finales segun su importancia por giro
mapeo_pesos = {}
mapeo_diccionario = {}

# %%
df_ventas.desc_marca.unique()
# Out:
# array(['BIG', 'CIFRUT', 'CIELO', 'PULP', 'VOLT', 'D GUSSTO', 'SPORADE',
#        'DESS', 'ORO', 'NUTRIDOG GOLD', 'BLING', 'DILYTE', 'KR', 'VIDA'],
#       dtype=object)

# %%
for giro_v in df_ventas["desc_subgiro"].unique():
    temp = df_ventas[(df_ventas["desc_subgiro"] == giro_v)]
    ranks = temp.groupby("desc_categoria")["cant_cajafisicavta"].sum().reset_index()
    ranks.columns = ["index","desc_categoria"]
    ranks = ranks.sort_values(by="desc_categoria", ascending=False)
    if len(list(ranks["desc_categoria"])) <= 5:
        ranks["Ranking"] = range(1, len(ranks) + 1)
    elif len(list(ranks["desc_categoria"])) > 5:
        a = list(ranks["desc_categoria"])
        b = [1, 1, 2, 2]
        # Calculamos el multiplicador para el mapeo de pesos segun la varianza
        if np.std(a) / np.mean(a) <= 1.2:
            multiplicador = 4
        else:
            multiplicador = 2
        if len(a) > 5:
            for i in range(4, len(a)):
                if a[3] <= a[i] * multiplicador:
                    b.append(3)
                else:
                    b.append(3 + i)
        ranks["Ranking"] = b

    print("*" * 20)
    print("GIRO: ", giro_v)
    print("Categorias: ", list(ranks["index"]))
    print("Counts: ", list(ranks["desc_categoria"]))
    print(ranks.set_index("index")["Ranking"].to_dict())
    mapeo_diccionario[giro_v] = ranks.set_index("index")["Ranking"].to_dict()
# Out:
# ********************
# GIRO:  BODEGAS, TIENDAS
# Categorias:  ['GASEOSAS', 'BEBIDAS DEPORTIVAS', 'AGUA', 'NECTAR', 'CITRUS', 'ENERGIZANTE', 'DETERGENTE', 'CAFE', 'MASCOTA', 'CONSERVA DE PESCADO', 'DESINFECTANTE', 'ACEITE', 'SUERO', 'GELATINA', 'LAVAVAJILLAS', 'SUAVIZANTES', 'MODIFICADORES LACTEOS', 'ARROZ', 'AVENA', 'PASTAS', 'CEREALES', 'SNACKS']
# Counts:  [920179.9999999991, 786649.5833333333, 536262.25, 496801.95833333326, 432864.31666666665, 174720.41666666666, 80546.83333333323, 36578.33333333332, 22263.0, 19996.541666666497, 16723.6666666665, 14036.458333333312, 7754.333333333054, 7109.333333333331, 2895.0, 2757.4999999999995, 2466.708333333332, 873.46, 729.5583333333333, 664.1, 139.3388888887984, 95.6608333333313]
# {'GASEOSAS': 1, 'BEBIDAS DEPORTIVAS': 1, 'AGUA': 2, 'NECTAR': 2, 'CITRUS': 3, 'ENERGIZANTE': 8, 'DETERGENTE': 9, 'CAFE': 10, 'MASCOTA': 11, 'CONSERVA DE PESCADO': 12, 'DESINFECTANTE': 13, 'ACEITE': 14, 'SUERO': 15, 'GELATINA': 16, 'LAVAVAJILLAS': 17, 'SUAVIZANTES': 18, 'MODIFICADORES LACTEOS': 19, 'ARROZ': 20, 'AVENA': 21, 'PASTAS': 22, 'CEREALES': 23, 'SNACKS': 24}
# ********************
# GIRO:  PANADERIA/PASTELERIA
# Categorias:  ['GASEOSAS', 'NECTAR', 'BEBIDAS DEPORTIVAS', 'CITRUS', 'AGUA', 'ENERGIZANTE', 'CAFE', 'DETERGENTE', 'CONSERVA DE PESCADO', 'ACEITE', 'DESINFECTANTE', 'MASCOTA', 'MODIFICADORES LACTEOS', 'SUERO', 'GELATINA', 'AVENA', 'LAVAVAJILLAS', 'SUAVIZANTES', 'ARROZ', 'PASTAS', 'SNACKS', 'CEREALES']
# Counts:  [125458.62499999977, 123619.12499999999, 86844.0, 86059.43333333333, 85120.05, 25184.666666666668, 7198.854166666665, 3882.958333333326, 1143.062499999987, 897.3333333333301, 842.9166666666599, 819.5, 655.2499999999998, 633.1666666666366, 607.6666666666664, 141.9625, 140.0, 114.0, 78.14, 25.6, 8.3225, 6.1999999999956]
# {'GASEOSAS': 1, 'NECTAR': 1, 'BEBIDAS DEPORTIVAS': 2, 'CITRUS': 2, 'AGUA': 3, 'ENERGIZANTE': 8, 'CAFE': 9, 'DETERGENTE': 10, 'CONSERVA DE PESCADO': 11, 'ACEITE': 12, 'DESINFECTANTE': 13, 'MASCOTA': 14, 'MODIFICADORES LACTEOS': 15, 'SUERO': 16, 'GELATINA': 17, 'AVENA': 18, 'LAVAVAJILLAS': 19, 'SUAVIZANTES': 20, 'ARROZ': 21, 'PASTAS': 22, 'SNACKS': 23, 'CEREALES': 24}
# ********************
# GIRO:  VENTA EN CASA PARTICULAR
# Categorias:  ['GASEOSAS', 'BEBIDAS DEPORTIVAS', 'AGUA', 'NECTAR', 'CITRUS', 'ENERGIZANTE', 'DETERGENTE', 'CAFE', 'MASCOTA', 'ACEITE', 'CONSERVA DE PESCADO', 'DESINFECTANTE', 'SUERO', 'SUAVIZANTES', 'LAVAVAJILLAS', 'GELATINA', 'MODIFICADORES LACTEOS', 'ARROZ', 'PASTAS', 'AVENA', 'CEREALES', 'SNACKS']
# Counts:  [98940.12499999993, 71738.75, 51445.85, 39909.70833333333, 36823.58333333333, 18700.75, 9395.49999999999, 4689.999999999998, 2382.75, 1630.0416666666642, 1410.854166666656, 1371.8333333333173, 820.4999999999709, 567.4999999999999, 410.0, 360.9999999999998, 290.6666666666665, 211.26, 49.949999999999996, 34.9, 30.661111111095, 20.062499999999602]
# {'GASEOSAS': 1, 'BEBIDAS DEPORTIVAS': 1, 'AGUA': 2, 'NECTAR': 2, 'CITRUS': 3, 'ENERGIZANTE': 8, 'DETERGENTE': 9, 'CAFE': 10, 'MASCOTA': 11, 'ACEITE': 12, 'CONSERVA DE PESCADO': 13, 'DESINFECTANTE': 14, 'SUERO': 15, 'SUAVIZANTES': 16, 'LAVAVAJILLAS': 17, 'GELATINA': 18, 'MODIFICADORES LACTEOS': 19, 'ARROZ': 20, 'PASTAS': 21, 'AVENA': 22, 'CEREALES': 23, 'SNACKS': 24}
# ********************
# GIRO:  MINIMARKET INDEPENDIENTE
# Categorias:  ['GASEOSAS', 'BEBIDAS DEPORTIVAS', 'NECTAR', 'AGUA', 'CITRUS', 'ENERGIZANTE', 'DETERGENTE', 'CONSERVA DE PESCADO', 'DESINFECTANTE', 'ACEITE', 'SUERO', 'MASCOTA', 'CAFE', 'GELATINA', 'LAVAVAJILLAS', 'ARROZ', 'AVENA', 'MODIFICADORES LACTEOS', 'PASTAS', 'SUAVIZANTES', 'SNACKS', 'CEREALES']
# Counts:  [72131.04166666663, 69699.58333333333, 47745.58333333333, 45456.5, 33488.166666666664, 19937.0, 5371.124999999995, 2136.10416666666, 1479.3333333333258, 1224.8749999999993, 1090.9999999999777, 943.5, 938.4999999999995, 755.5, 180.0, 124.42, 119.7875, 80.0833333333332, 57.15, 35.0, 2.7625, 0.9333333333325]
# {'GASEOSAS': 1, 'BEBIDAS DEPORTIVAS': 1, 'NECTAR': 2, 'AGUA': 2, 'CITRUS': 3, 'ENERGIZANTE': 8, 'DETERGENTE': 9, 'CONSERVA DE PESCADO': 10, 'DESINFECTANTE': 11, 'ACEITE': 12, 'SUERO': 13, 'MASCOTA': 14, 'CAFE': 15, 'GELATINA': 16, 'LAVAVAJILLAS': 17, 'ARROZ': 18, 'AVENA': 19, 'MODIFICADORES LACTEOS': 20, 'PASTAS': 21, 'SUAVIZANTES': 22, 'SNACKS': 23, 'CEREALES': 24}
# ********************
# GIRO:  LICORERIAS
# Categorias:  ['BEBIDAS DEPORTIVAS', 'GASEOSAS', 'AGUA', 'CITRUS', 'NECTAR', 'ENERGIZANTE', 'DETERGENTE', 'CAFE', 'DESINFECTANTE', 'ACEITE', 'MASCOTA', 'SUERO', 'CONSERVA DE PESCADO', 'LAVAVAJILLAS', 'GELATINA', 'SUAVIZANTES', 'MODIFICADORES LACTEOS', 'AVENA', 'PASTAS', 'ARROZ', 'SNACKS', 'CEREALES']
# Counts:  [26699.333333333332, 19087.458333333314, 17274.166666666668, 11799.383333333333, 7856.041666666666, 5398.666666666667, 1599.4999999999986, 517.8541666666667, 329.666666666664, 275.3749999999995, 271.75, 241.8333333333246, 204.4791666666647, 56.0, 50.0, 43.0, 21.6666666666666, 10.2625, 8.75, 7.54, 1.6400000000000001, 0.2666666666664]
# {'BEBIDAS DEPORTIVAS': 1, 'GASEOSAS': 1, 'AGUA': 2, 'CITRUS': 2, 'NECTAR': 3, 'ENERGIZANTE': 8, 'DETERGENTE': 9, 'CAFE': 10, 'DESINFECTANTE': 11, 'ACEITE': 12, 'MASCOTA': 13, 'SUERO': 14, 'CONSERVA DE PESCADO': 15, 'LAVAVAJILLAS': 16, 'GELATINA': 17, 'SUAVIZANTES': 18, 'MODIFICADORES LACTEOS': 19, 'AVENA': 20, 'PASTAS': 21, 'ARROZ': 22, 'SNACKS': 23, 'CEREALES': 24}
# ********************
# GIRO:  OTROS TRADICIONAL
# Categorias:  ['GASEOSAS', 'BEBIDAS DEPORTIVAS', 'AGUA', 'NECTAR', 'CITRUS', 'ENERGIZANTE', 'DETERGENTE', 'ACEITE', 'CAFE', 'MASCOTA', 'SUERO', 'CONSERVA DE PESCADO', 'DESINFECTANTE', 'GELATINA', 'LAVAVAJILLAS', 'MODIFICADORES LACTEOS', 'SUAVIZANTES', 'PASTAS', 'ARROZ', 'SNACKS', 'AVENA', 'CEREALES']
# Counts:  [4607.666666666661, 4148.666666666667, 3733.8333333333335, 1979.75, 1542.9166666666667, 1073.0, 282.9999999999996, 133.74999999999972, 105.1041666666664, 51.75, 44.1666666666649, 41.3749999999997, 37.4166666666662, 27.0, 18.0, 11.5, 10.0, 1.65, 1.64, 0.8825000000000001, 0.7625, 0.1999999999998]
# {'GASEOSAS': 1, 'BEBIDAS DEPORTIVAS': 1, 'AGUA': 2, 'NECTAR': 2, 'CITRUS': 3, 'ENERGIZANTE': 3, 'DETERGENTE': 9, 'ACEITE': 10, 'CAFE': 11, 'MASCOTA': 12, 'SUERO': 13, 'CONSERVA DE PESCADO': 14, 'DESINFECTANTE': 15, 'GELATINA': 16, 'LAVAVAJILLAS': 17, 'MODIFICADORES LACTEOS': 18, 'SUAVIZANTES': 19, 'PASTAS': 20, 'ARROZ': 21, 'SNACKS': 22, 'AVENA': 23, 'CEREALES': 24}
# ********************
# GIRO:  KIOSKO
# Categorias:  ['AGUA', 'BEBIDAS DEPORTIVAS', 'GASEOSAS', 'NECTAR', 'CITRUS', 'ENERGIZANTE', 'DETERGENTE', 'CAFE', 'CONSERVA DE PESCADO', 'DESINFECTANTE', 'MASCOTA', 'GELATINA', 'ACEITE', 'SUERO', 'AVENA', 'LAVAVAJILLAS', 'MODIFICADORES LACTEOS', 'SUAVIZANTES', 'PASTAS', 'ARROZ', 'CEREALES', 'SNACKS']
# Counts:  [10753.666666666666, 10464.333333333334, 6872.208333333321, 3712.333333333333, 2772.933333333332, 2372.5, 314.2083333333324, 130.7916666666665, 85.2708333333323, 80.9999999999993, 78.25, 70.0, 66.9166666666665, 47.9999999999981, 21.5208333333332, 16.0, 14.0416666666666, 14.0, 7.25, 6.88, 1.1999999999998, 0.5]
# {'AGUA': 1, 'BEBIDAS DEPORTIVAS': 1, 'GASEOSAS': 2, 'NECTAR': 2, 'CITRUS': 3, 'ENERGIZANTE': 3, 'DETERGENTE': 9, 'CAFE': 10, 'CONSERVA DE PESCADO': 11, 'DESINFECTANTE': 12, 'MASCOTA': 13, 'GELATINA': 14, 'ACEITE': 15, 'SUERO': 16, 'AVENA': 17, 'LAVAVAJILLAS': 18, 'MODIFICADORES LACTEOS': 19, 'SUAVIZANTES': 20, 'PASTAS': 21, 'ARROZ': 22, 'CEREALES': 23, 'SNACKS': 24}
# ********************
# GIRO:  FARMACIAS / BOTICAS INDEPENDIENTES
# Categorias:  ['BEBIDAS DEPORTIVAS', 'AGUA', 'GASEOSAS', 'ENERGIZANTE', 'NECTAR', 'CITRUS', 'SUERO', 'DETERGENTE', 'CAFE', 'DESINFECTANTE', 'CONSERVA DE PESCADO', 'MASCOTA', 'ACEITE', 'GELATINA', 'SUAVIZANTES', 'LAVAVAJILLAS', 'MODIFICADORES LACTEOS', 'ARROZ', 'PASTAS', 'CEREALES', 'SNACKS', 'AVENA']
# Counts:  [7151.666666666666, 6830.0, 3373.249999999996, 1856.0, 1821.3333333333328, 1188.0666666666664, 766.3333333333188, 261.0833333333327, 111.7291666666666, 101.3333333333331, 76.1874999999995, 56.5, 21.2499999999999, 17.0, 7.0, 7.0, 3.5, 3.4, 1.85, 0.25555555555529996, 0.23, 0.0625]
# {'BEBIDAS DEPORTIVAS': 1, 'AGUA': 1, 'GASEOSAS': 2, 'ENERGIZANTE': 2, 'NECTAR': 3, 'CITRUS': 3, 'SUERO': 9, 'DETERGENTE': 10, 'CAFE': 11, 'DESINFECTANTE': 12, 'CONSERVA DE PESCADO': 13, 'MASCOTA': 14, 'ACEITE': 15, 'GELATINA': 16, 'SUAVIZANTES': 17, 'LAVAVAJILLAS': 18, 'MODIFICADORES LACTEOS': 19, 'ARROZ': 20, 'PASTAS': 21, 'CEREALES': 22, 'SNACKS': 23, 'AVENA': 24}
# ********************
# GIRO:  RESTAURANT TRADICIONAL
# Categorias:  ['GASEOSAS', 'AGUA', 'BEBIDAS DEPORTIVAS', 'NECTAR', 'CITRUS', 'ENERGIZANTE', 'DETERGENTE', 'CAFE', 'DESINFECTANTE', 'MASCOTA', 'CONSERVA DE PESCADO', 'SUERO', 'ACEITE', 'GELATINA', 'LAVAVAJILLAS', 'PASTAS', 'MODIFICADORES LACTEOS', 'SUAVIZANTES', 'ARROZ', 'AVENA', 'SNACKS', 'CEREALES']
# Counts:  [19990.874999999953, 19409.366666666665, 17080.416666666664, 9350.416666666666, 6203.416666666666, 4854.583333333333, 1589.3333333333312, 493.1249999999994, 283.9999999999986, 255.0, 246.5208333333315, 201.6666666666617, 194.9999999999997, 122.0, 93.0, 66.4, 61.2499999999999, 34.0, 4.8, 3.3750000000000004, 2.0933333333332, 0.938888888888]
# {'GASEOSAS': 1, 'AGUA': 1, 'BEBIDAS DEPORTIVAS': 2, 'NECTAR': 2, 'CITRUS': 3, 'ENERGIZANTE': 3, 'DETERGENTE': 9, 'CAFE': 10, 'DESINFECTANTE': 11, 'MASCOTA': 12, 'CONSERVA DE PESCADO': 13, 'SUERO': 14, 'ACEITE': 15, 'GELATINA': 16, 'LAVAVAJILLAS': 17, 'PASTAS': 18, 'MODIFICADORES LACTEOS': 19, 'SUAVIZANTES': 20, 'ARROZ': 21, 'AVENA': 22, 'SNACKS': 23, 'CEREALES': 24}
# ********************
# GIRO:  FRUTERIAS/VERDULERIAS
# Categorias:  ['AGUA', 'GASEOSAS', 'BEBIDAS DEPORTIVAS', 'NECTAR', 'CITRUS', 'ENERGIZANTE', 'DETERGENTE', 'CONSERVA DE PESCADO', 'GELATINA', 'DESINFECTANTE', 'CAFE', 'ACEITE', 'MASCOTA', 'LAVAVAJILLAS', 'SUERO', 'MODIFICADORES LACTEOS', 'AVENA', 'SUAVIZANTES', 'PASTAS', 'SNACKS', 'CEREALES']
# Counts:  [2999.0, 2667.3333333333244, 2395.6666666666665, 1915.0, 1755.9999999999998, 478.8333333333333, 164.0833333333332, 152.2708333333326, 82.9999999999999, 72.6666666666658, 71.625, 58.3333333333332, 33.75, 24.0, 15.9999999999993, 8.5, 5.775, 4.0, 2.6, 0.1, 0.0666666666666]
# {'AGUA': 1, 'GASEOSAS': 1, 'BEBIDAS DEPORTIVAS': 2, 'NECTAR': 2, 'CITRUS': 3, 'ENERGIZANTE': 8, 'DETERGENTE': 9, 'CONSERVA DE PESCADO': 10, 'GELATINA': 11, 'DESINFECTANTE': 12, 'CAFE': 13, 'ACEITE': 14, 'MASCOTA': 15, 'LAVAVAJILLAS': 16, 'SUERO': 17, 'MODIFICADORES LACTEOS': 18, 'AVENA': 19, 'SUAVIZANTES': 20, 'PASTAS': 21, 'SNACKS': 22, 'CEREALES': 23}
# ********************
# GIRO:  CARNICERIAS/PESCADERIA/VENTA POLLOS
# Categorias:  ['BEBIDAS DEPORTIVAS', 'AGUA', 'GASEOSAS', 'NECTAR', 'CITRUS', 'ENERGIZANTE', 'DETERGENTE', 'CAFE', 'ACEITE', 'CONSERVA DE PESCADO', 'SUERO', 'DESINFECTANTE', 'MASCOTA', 'GELATINA', 'PASTAS', 'SUAVIZANTES', 'MODIFICADORES LACTEOS', 'AVENA', 'ARROZ', 'SNACKS']
# Counts:  [1731.5, 1362.0, 1136.9999999999984, 925.0, 715.0, 361.0, 163.083333333333, 107.6041666666666, 71.4166666666666, 53.9374999999997, 42.9999999999991, 41.8333333333328, 22.0, 20.0, 8.299999999999999, 5.0, 3.0, 2.6375, 0.12, 0.1]
# {'BEBIDAS DEPORTIVAS': 1, 'AGUA': 1, 'GASEOSAS': 2, 'NECTAR': 2, 'CITRUS': 3, 'ENERGIZANTE': 8, 'DETERGENTE': 9, 'CAFE': 10, 'ACEITE': 11, 'CONSERVA DE PESCADO': 12, 'SUERO': 13, 'DESINFECTANTE': 14, 'MASCOTA': 15, 'GELATINA': 16, 'PASTAS': 17, 'SUAVIZANTES': 18, 'MODIFICADORES LACTEOS': 19, 'AVENA': 20, 'ARROZ': 21, 'SNACKS': 22}
# ********************
# GIRO:  ABARROTERO
# Categorias:  ['GASEOSAS', 'BEBIDAS DEPORTIVAS', 'AGUA', 'CITRUS', 'NECTAR', 'ENERGIZANTE', 'DETERGENTE', 'CAFE', 'ACEITE', 'DESINFECTANTE', 'CONSERVA DE PESCADO', 'MASCOTA', 'GELATINA', 'SUERO', 'SUAVIZANTES', 'LAVAVAJILLAS', 'MODIFICADORES LACTEOS', 'PASTAS', 'AVENA', 'ARROZ', 'SNACKS', 'CEREALES']
# Counts:  [21014.708333333296, 17722.75, 13514.666666666666, 8477.583333333332, 7292.5, 2949.0, 1427.1666666666642, 453.1666666666663, 333.7083333333331, 313.416666666664, 284.9374999999981, 265.25, 197.1666666666666, 141.4999999999951, 64.0, 42.0, 36.4583333333333, 11.55, 10.325, 2.06, 1.8883333333333001, 1.1999999999992]
# {'GASEOSAS': 1, 'BEBIDAS DEPORTIVAS': 1, 'AGUA': 2, 'CITRUS': 2, 'NECTAR': 3, 'ENERGIZANTE': 8, 'DETERGENTE': 9, 'CAFE': 10, 'ACEITE': 11, 'DESINFECTANTE': 12, 'CONSERVA DE PESCADO': 13, 'MASCOTA': 14, 'GELATINA': 15, 'SUERO': 16, 'SUAVIZANTES': 17, 'LAVAVAJILLAS': 18, 'MODIFICADORES LACTEOS': 19, 'PASTAS': 20, 'AVENA': 21, 'ARROZ': 22, 'SNACKS': 23, 'CEREALES': 24}
# ********************
# GIRO:  GIMNASIO TRADICIONAL
# Categorias:  ['AGUA', 'BEBIDAS DEPORTIVAS', 'GASEOSAS', 'ENERGIZANTE', 'SUERO', 'NECTAR', 'CITRUS', 'DETERGENTE', 'CONSERVA DE PESCADO', 'CAFE', 'MASCOTA']
# Counts:  [1663.0, 747.5, 205.4999999999996, 155.5, 127.6666666666652, 55.0, 25.3333333333333, 17.25, 3.4583333333333, 2.125, 1.0]
# {'AGUA': 1, 'BEBIDAS DEPORTIVAS': 1, 'GASEOSAS': 2, 'ENERGIZANTE': 2, 'SUERO': 3, 'NECTAR': 8, 'CITRUS': 9, 'DETERGENTE': 10, 'CONSERVA DE PESCADO': 11, 'CAFE': 12, 'MASCOTA': 13}
# ********************
# GIRO:  BEBIBLES
# Categorias:  ['GASEOSAS', 'BEBIDAS DEPORTIVAS', 'AGUA', 'ENERGIZANTE', 'NECTAR', 'CITRUS', 'CAFE', 'DETERGENTE', 'MASCOTA', 'CONSERVA DE PESCADO', 'DESINFECTANTE', 'GELATINA', 'SUERO', 'SUAVIZANTES', 'ACEITE', 'SNACKS', 'ARROZ']
# Counts:  [2500.874999999999, 1961.6666666666665, 634.0, 475.5, 369.0, 259.9999999999999, 31.0833333333334, 20.0, 16.0, 9.5833333333333, 6.9999999999999005, 6.0, 2.0, 2.0, 1.75, 0.6000000000000001, 0.56]
# {'GASEOSAS': 1, 'BEBIDAS DEPORTIVAS': 1, 'AGUA': 2, 'ENERGIZANTE': 2, 'NECTAR': 3, 'CITRUS': 3, 'CAFE': 9, 'DETERGENTE': 10, 'MASCOTA': 11, 'CONSERVA DE PESCADO': 12, 'DESINFECTANTE': 13, 'GELATINA': 14, 'SUERO': 15, 'SUAVIZANTES': 16, 'ACEITE': 17, 'SNACKS': 18, 'ARROZ': 19}
# ********************
# GIRO:  GRIFO/AUTOLAVADO TRADICIONAL
# Categorias:  ['BEBIDAS DEPORTIVAS', 'NECTAR', 'GASEOSAS', 'ENERGIZANTE', 'AGUA', 'CITRUS', 'DETERGENTE', 'GELATINA', 'LAVAVAJILLAS', 'CAFE', 'MASCOTA', 'CONSERVA DE PESCADO', 'SNACKS', 'MODIFICADORES LACTEOS']
# Counts:  [316.0, 132.0, 82.0, 73.0, 69.0, 47.0, 42.1666666666666, 4.0, 4.0, 2.0, 1.0, 0.8333333333333, 0.16, 0.0]
# {'BEBIDAS DEPORTIVAS': 1, 'NECTAR': 1, 'GASEOSAS': 2, 'ENERGIZANTE': 2, 'AGUA': 3, 'CITRUS': 3, 'DETERGENTE': 3, 'GELATINA': 10, 'LAVAVAJILLAS': 11, 'CAFE': 12, 'MASCOTA': 13, 'CONSERVA DE PESCADO': 14, 'SNACKS': 15, 'MODIFICADORES LACTEOS': 16}
# ********************
# GIRO:  LIMPIEZA
# Categorias:  ['BEBIDAS DEPORTIVAS', 'AGUA', 'GASEOSAS', 'CITRUS', 'ENERGIZANTE', 'NECTAR', 'DETERGENTE', 'SUERO', 'LAVAVAJILLAS', 'CONSERVA DE PESCADO', 'GELATINA', 'ACEITE', 'CAFE', 'SUAVIZANTES']
# Counts:  [202.0, 195.0, 131.1666666666664, 72.0, 67.0, 43.0, 32.1666666666665, 13.3333333333332, 5.0, 4.4791666666667, 2.0, 1.25, 1.0, 1.0]
# {'BEBIDAS DEPORTIVAS': 1, 'AGUA': 1, 'GASEOSAS': 2, 'CITRUS': 2, 'ENERGIZANTE': 3, 'NECTAR': 3, 'DETERGENTE': 9, 'SUERO': 10, 'LAVAVAJILLAS': 11, 'CONSERVA DE PESCADO': 12, 'GELATINA': 13, 'ACEITE': 14, 'CAFE': 15, 'SUAVIZANTES': 16}
# ********************
# GIRO:  GOLOSINERO
# Categorias:  ['GASEOSAS', 'BEBIDAS DEPORTIVAS', 'NECTAR', 'CITRUS', 'ENERGIZANTE', 'AGUA', 'DESINFECTANTE', 'DETERGENTE', 'LAVAVAJILLAS', 'CONSERVA DE PESCADO', 'CAFE', 'MASCOTA', 'ACEITE', 'ARROZ', 'AVENA']
# Counts:  [319.0, 277.0, 116.0, 99.0, 68.0, 39.0, 36.0, 10.5, 6.0, 5.8333333333332, 5.3958333333333, 2.0, 1.0, 0.6, 0.075]
# {'GASEOSAS': 1, 'BEBIDAS DEPORTIVAS': 1, 'NECTAR': 2, 'CITRUS': 2, 'ENERGIZANTE': 3, 'AGUA': 8, 'DESINFECTANTE': 9, 'DETERGENTE': 10, 'LAVAVAJILLAS': 11, 'CONSERVA DE PESCADO': 12, 'CAFE': 13, 'MASCOTA': 14, 'ACEITE': 15, 'ARROZ': 16, 'AVENA': 17}
# ********************
# GIRO:  CAFE/SALON DE TE/PANADERIA
# Categorias:  ['NECTAR', 'GASEOSAS', 'AGUA', 'CITRUS', 'BEBIDAS DEPORTIVAS', 'CAFE', 'ENERGIZANTE', 'SUERO', 'MASCOTA', 'ACEITE', 'CONSERVA DE PESCADO']
# Counts:  [213.0, 143.9999999999988, 111.0, 85.0, 78.0, 11.125, 5.0, 1.0, 1.0, 0.5833333333333, 0.125]
# {'NECTAR': 1, 'GASEOSAS': 1, 'AGUA': 2, 'CITRUS': 2, 'BEBIDAS DEPORTIVAS': 3, 'CAFE': 8, 'ENERGIZANTE': 9, 'SUERO': 10, 'MASCOTA': 11, 'ACEITE': 12, 'CONSERVA DE PESCADO': 13}
# ********************
# GIRO:  MODULO/PUESTO MOVIL/CARRETILLA /CHASA
# Categorias:  ['AGUA', 'GASEOSAS', 'NECTAR', 'BEBIDAS DEPORTIVAS', 'CITRUS', 'ENERGIZANTE', 'SUERO', 'DESINFECTANTE']
# Counts:  [85.0, 61.0, 57.0, 40.0, 12.0, 8.0, 1.0, 0.9999999999999001]
# {'AGUA': 1, 'GASEOSAS': 1, 'NECTAR': 2, 'BEBIDAS DEPORTIVAS': 2, 'CITRUS': 3, 'ENERGIZANTE': 8, 'SUERO': 9, 'DESINFECTANTE': 10}
# ********************
# GIRO:  AGENCIAS TRADICIONALES
# Categorias:  ['AGUA', 'BEBIDAS DEPORTIVAS', 'CITRUS', 'NECTAR', 'ENERGIZANTE', 'DETERGENTE', 'CAFE', 'GASEOSAS', 'ACEITE']
# Counts:  [76.0, 36.0, 12.0, 11.0, 11.0, 2.0, 2.0, 2.0, 1.0]
# {'AGUA': 1, 'BEBIDAS DEPORTIVAS': 1, 'CITRUS': 2, 'NECTAR': 2, 'ENERGIZANTE': 3, 'DETERGENTE': 8, 'CAFE': 9, 'GASEOSAS': 10, 'ACEITE': 11}
# ********************
# GIRO:  MINIMARKETS CADENA
# Categorias:  ['AGUA', 'NECTAR', 'CITRUS', 'BEBIDAS DEPORTIVAS', 'GASEOSAS', 'ENERGIZANTE', 'CONSERVA DE PESCADO', 'PASTAS']
# Counts:  [133.0, 131.0, 85.9999999999998, 64.0, 29.0, 17.0, 3.625, 1.6]
# {'AGUA': 1, 'NECTAR': 1, 'CITRUS': 2, 'BEBIDAS DEPORTIVAS': 2, 'GASEOSAS': 3, 'ENERGIZANTE': 3, 'CONSERVA DE PESCADO': 9, 'PASTAS': 10}
# ********************
# GIRO:  EXPENDIO DE COMIDAS
# Categorias:  ['GASEOSAS', 'CITRUS', 'AGUA', 'BEBIDAS DEPORTIVAS', 'ENERGIZANTE', 'NECTAR', 'DETERGENTE', 'LAVAVAJILLAS', 'CONSERVA DE PESCADO']
# Counts:  [214.0, 38.0, 28.0, 18.0, 17.0, 8.0, 6.0, 1.0, 0.3749999999999]
# {'GASEOSAS': 1, 'CITRUS': 1, 'AGUA': 2, 'BEBIDAS DEPORTIVAS': 2, 'ENERGIZANTE': 3, 'NECTAR': 8, 'DETERGENTE': 9, 'LAVAVAJILLAS': 10, 'CONSERVA DE PESCADO': 11}

# %% [markdown]
# ## 3.2. Filtro de SKU por Ruta
# Cada Ruta tiene una cantidad de SKUs distintos, la recomendacion será distinta para cada ruta, sin embargo, aquellas rutas que tengan pocos SKUs serán tratadas como una sola ruta

# %%
rutas = (
    df_ventas.groupby(["cod_ruta"])["id_cliente"]
    .nunique()
    .sort_values(ascending=False)
    .reset_index()["cod_ruta"]
    .unique()
)

# %%
low_sku_ruta = []

# %% [markdown]
# **Para rutas que tengan más de 45 SKUS**

# %%
for ruta in rutas:
    print("*" * 21)
    print("Ruta:", ruta)
    temp = df_ventas[(df_ventas["cod_ruta"] == ruta)]
    print("SKUs disponibles:", temp["cod_articulo_magic"].nunique())
    # print(f"Giros en ruta {ruta}:")
    # print(temp.groupby(["desc_giro"])["id_cliente"].nunique(dropna=False))
    if temp["cod_articulo_magic"].nunique() < 10:
        low_sku_ruta.append(ruta)
    else:
        temp.to_csv(f"Processed/rutas/D_{ruta}_ventas.csv", index=False)
# Out:
# *********************
# Ruta: 3411
# SKUs disponibles: 108
# *********************
# Ruta: 4217
# SKUs disponibles: 110
# *********************
# Ruta: 5404
# SKUs disponibles: 112
# *********************
# Ruta: 3304
# SKUs disponibles: 119
# *********************
# Ruta: 4903
# SKUs disponibles: 112
# *********************
# Ruta: 4504
# SKUs disponibles: 109
# *********************
# Ruta: 2706
# SKUs disponibles: 120
# *********************
# Ruta: 3303
# SKUs disponibles: 126
# *********************
# Ruta: 5204
# SKUs disponibles: 113
# *********************
# Ruta: 1309
# SKUs disponibles: 109
# *********************
# Ruta: 2717
# SKUs disponibles: 104
# *********************
# Ruta: 2904
# SKUs disponibles: 113
# *********************
# Ruta: 2804
# SKUs disponibles: 116
# *********************
# Ruta: 3403
# SKUs disponibles: 114
# *********************
# Ruta: 3811
# SKUs disponibles: 106
# *********************
# Ruta: 1217
# SKUs disponibles: 99
# *********************
# Ruta: 1917
# SKUs disponibles: 105
# *********************
# Ruta: 1904
# SKUs disponibles: 119
# *********************
# Ruta: 4517
# SKUs disponibles: 106
# *********************
# Ruta: 4604
# SKUs disponibles: 107
# *********************
# Ruta: 3504
# SKUs disponibles: 117
# *********************
# Ruta: 4711
# SKUs disponibles: 107
# *********************
# Ruta: 5703
# SKUs disponibles: 104
# *********************
# Ruta: 2011
# SKUs disponibles: 106
# *********************
# Ruta: 3211
# SKUs disponibles: 102
# *********************
# Ruta: 1417
# SKUs disponibles: 103
# *********************
# Ruta: 2107
# SKUs disponibles: 114
# *********************
# Ruta: 4704
# SKUs disponibles: 100
# *********************
# Ruta: 2809
# SKUs disponibles: 102
# *********************
# Ruta: 4804
# SKUs disponibles: 113
# *********************
# Ruta: 1211
# SKUs disponibles: 108
# *********************
# Ruta: 2307
# SKUs disponibles: 111
# *********************
# Ruta: 2411
# SKUs disponibles: 99
# *********************
# Ruta: 5104
# SKUs disponibles: 105
# *********************
# Ruta: 2504
# SKUs disponibles: 124
# *********************
# Ruta: 2209
# SKUs disponibles: 115
# *********************
# Ruta: 1911
# SKUs disponibles: 108
# *********************
# Ruta: 1706
# SKUs disponibles: 116
# *********************
# Ruta: 2106
# SKUs disponibles: 114
# *********************
# Ruta: 2111
# SKUs disponibles: 103
# *********************
# Ruta: 3117
# SKUs disponibles: 100
# *********************
# Ruta: 1704
# SKUs disponibles: 119
# *********************
# Ruta: 3611
# SKUs disponibles: 104
# *********************
# Ruta: 4904
# SKUs disponibles: 114
# *********************
# Ruta: 1403
# SKUs disponibles: 111
# *********************
# Ruta: 1104
# SKUs disponibles: 111
# *********************
# Ruta: 4617
# SKUs disponibles: 107
# *********************
# Ruta: 1108
# SKUs disponibles: 110
# *********************
# Ruta: 3104
# SKUs disponibles: 115
# *********************
# Ruta: 2911
# SKUs disponibles: 102
# *********************
# Ruta: 3517
# SKUs disponibles: 117
# *********************
# Ruta: 2008
# SKUs disponibles: 111
# *********************
# Ruta: 3011
# SKUs disponibles: 107
# *********************
# Ruta: 3204
# SKUs disponibles: 115
# *********************
# Ruta: 1517
# SKUs disponibles: 108
# *********************
# Ruta: 5603
# SKUs disponibles: 110
# *********************
# Ruta: 2404
# SKUs disponibles: 113
# *********************
# Ruta: 2304
# SKUs disponibles: 105
# *********************
# Ruta: 2417
# SKUs disponibles: 110
# *********************
# Ruta: 3806
# SKUs disponibles: 121
# *********************
# Ruta: 1607
# SKUs disponibles: 112
# *********************
# Ruta: 2311
# SKUs disponibles: 105
# *********************
# Ruta: 2406
# SKUs disponibles: 117
# *********************
# Ruta: 1906
# SKUs disponibles: 112
# *********************
# Ruta: 2204
# SKUs disponibles: 107
# *********************
# Ruta: 2611
# SKUs disponibles: 107
# *********************
# Ruta: 2704
# SKUs disponibles: 108
# *********************
# Ruta: 3111
# SKUs disponibles: 110
# *********************
# Ruta: 3004
# SKUs disponibles: 121
# *********************
# Ruta: 2009
# SKUs disponibles: 108
# *********************
# Ruta: 1504
# SKUs disponibles: 115
# *********************
# Ruta: 1308
# SKUs disponibles: 107
# *********************
# Ruta: 1011
# SKUs disponibles: 108
# *********************
# Ruta: 1609
# SKUs disponibles: 105
# *********************
# Ruta: 1804
# SKUs disponibles: 116
# *********************
# Ruta: 2306
# SKUs disponibles: 111
# *********************
# Ruta: 3911
# SKUs disponibles: 103
# *********************
# Ruta: 1809
# SKUs disponibles: 109
# *********************
# Ruta: 2709
# SKUs disponibles: 107
# *********************
# Ruta: 1408
# SKUs disponibles: 105
# *********************
# Ruta: 2211
# SKUs disponibles: 108
# *********************
# Ruta: 2604
# SKUs disponibles: 112
# *********************
# Ruta: 1304
# SKUs disponibles: 119
# *********************
# Ruta: 1204
# SKUs disponibles: 111
# *********************
# Ruta: 3404
# SKUs disponibles: 115
# *********************
# Ruta: 2517
# SKUs disponibles: 96
# *********************
# Ruta: 3511
# SKUs disponibles: 109
# *********************
# Ruta: 1409
# SKUs disponibles: 108
# *********************
# Ruta: 2711
# SKUs disponibles: 111
# *********************
# Ruta: 2407
# SKUs disponibles: 106
# *********************
# Ruta: 1808
# SKUs disponibles: 103
# *********************
# Ruta: 1608
# SKUs disponibles: 107
# *********************
# Ruta: 1806
# SKUs disponibles: 114
# *********************
# Ruta: 4017
# SKUs disponibles: 112
# *********************
# Ruta: 1604
# SKUs disponibles: 106
# *********************
# Ruta: 2109
# SKUs disponibles: 108
# *********************
# Ruta: 1807
# SKUs disponibles: 106
# *********************
# Ruta: 2207
# SKUs disponibles: 98
# *********************
# Ruta: 2811
# SKUs disponibles: 107
# *********************
# Ruta: 3106
# SKUs disponibles: 124
# *********************
# Ruta: 2208
# SKUs disponibles: 106
# *********************
# Ruta: 2006
# SKUs disponibles: 114
# *********************
# Ruta: 3217
# SKUs disponibles: 101
# *********************
# Ruta: 4917
# SKUs disponibles: 110
# *********************
# Ruta: 1506
# SKUs disponibles: 116
# *********************
# Ruta: 1907
# SKUs disponibles: 106
# *********************
# Ruta: 3311
# SKUs disponibles: 107
# *********************
# Ruta: 1306
# SKUs disponibles: 118
# *********************
# Ruta: 1208
# SKUs disponibles: 104
# *********************
# Ruta: 1511
# SKUs disponibles: 101
# *********************
# Ruta: 2206
# SKUs disponibles: 115
# *********************
# Ruta: 1206
# SKUs disponibles: 114
# *********************
# Ruta: 1404
# SKUs disponibles: 120
# *********************
# Ruta: 3917
# SKUs disponibles: 111
# *********************
# Ruta: 1717
# SKUs disponibles: 101
# *********************
# Ruta: 3507
# SKUs disponibles: 104
# *********************
# Ruta: 2108
# SKUs disponibles: 109
# *********************
# Ruta: 1103
# SKUs disponibles: 112
# *********************
# Ruta: 1611
# SKUs disponibles: 109
# *********************
# Ruta: 1711
# SKUs disponibles: 99
# *********************
# Ruta: 4811
# SKUs disponibles: 107
# *********************
# Ruta: 2004
# SKUs disponibles: 114
# *********************
# Ruta: 2104
# SKUs disponibles: 104
# *********************
# Ruta: 2003
# SKUs disponibles: 107
# *********************
# Ruta: 1311
# SKUs disponibles: 110
# *********************
# Ruta: 2511
# SKUs disponibles: 101
# *********************
# Ruta: 1209
# SKUs disponibles: 105
# *********************
# Ruta: 2617
# SKUs disponibles: 101
# *********************
# Ruta: 1411
# SKUs disponibles: 104
# *********************
# Ruta: 2807
# SKUs disponibles: 105
# *********************
# Ruta: 2817
# SKUs disponibles: 117
# *********************
# Ruta: 4117
# SKUs disponibles: 99
# *********************
# Ruta: 2703
# SKUs disponibles: 111
# *********************
# Ruta: 1009
# SKUs disponibles: 105
# *********************
# Ruta: 1008
# SKUs disponibles: 114
# *********************
# Ruta: 1004
# SKUs disponibles: 105
# *********************
# Ruta: 1909
# SKUs disponibles: 97
# *********************
# Ruta: 1709
# SKUs disponibles: 109
# *********************
# Ruta: 1908
# SKUs disponibles: 108
# *********************
# Ruta: 2917
# SKUs disponibles: 108
# *********************
# Ruta: 2303
# SKUs disponibles: 91
# *********************
# Ruta: 2806
# SKUs disponibles: 110
# *********************
# Ruta: 4317
# SKUs disponibles: 106
# *********************
# Ruta: 4011
# SKUs disponibles: 109
# *********************
# Ruta: 2606
# SKUs disponibles: 121
# *********************
# Ruta: 2403
# SKUs disponibles: 120
# *********************
# Ruta: 2607
# SKUs disponibles: 104
# *********************
# Ruta: 1606
# SKUs disponibles: 112
# *********************
# Ruta: 1006
# SKUs disponibles: 118
# *********************
# Ruta: 1817
# SKUs disponibles: 112
# *********************
# Ruta: 3607
# SKUs disponibles: 109
# *********************
# Ruta: 1811
# SKUs disponibles: 110
# *********************
# Ruta: 4106
# SKUs disponibles: 119
# *********************
# Ruta: 1803
# SKUs disponibles: 116
# *********************
# Ruta: 1617
# SKUs disponibles: 109
# *********************
# Ruta: 1117
# SKUs disponibles: 107
# *********************
# Ruta: 2017
# SKUs disponibles: 108
# *********************
# Ruta: 2707
# SKUs disponibles: 97
# *********************
# Ruta: 1317
# SKUs disponibles: 100
# *********************
# Ruta: 4417
# SKUs disponibles: 109
# *********************
# Ruta: 3003
# SKUs disponibles: 113
# *********************
# Ruta: 2203
# SKUs disponibles: 111
# *********************
# Ruta: 2408
# SKUs disponibles: 112
# *********************
# Ruta: 1107
# SKUs disponibles: 94
# *********************
# Ruta: 1407
# SKUs disponibles: 103
# *********************
# Ruta: 1003
# SKUs disponibles: 114
# *********************
# Ruta: 1203
# SKUs disponibles: 114
# *********************
# Ruta: 3604
# SKUs disponibles: 121
# *********************
# Ruta: 2803
# SKUs disponibles: 117
# *********************
# Ruta: 1307
# SKUs disponibles: 104
# *********************
# Ruta: 1507
# SKUs disponibles: 105
# *********************
# Ruta: 2007
# SKUs disponibles: 103
# *********************
# Ruta: 2906
# SKUs disponibles: 111
# *********************
# Ruta: 2609
# SKUs disponibles: 99
# *********************
# Ruta: 1207
# SKUs disponibles: 104
# *********************
# Ruta: 2503
# SKUs disponibles: 113
# *********************
# Ruta: 2103
# SKUs disponibles: 111
# *********************
# Ruta: 1303
# SKUs disponibles: 113
# *********************
# Ruta: 5203
# SKUs disponibles: 110
# *********************
# Ruta: 1703
# SKUs disponibles: 119
# *********************
# Ruta: 1708
# SKUs disponibles: 112
# *********************
# Ruta: 4703
# SKUs disponibles: 103
# *********************
# Ruta: 4717
# SKUs disponibles: 104
# *********************
# Ruta: 1007
# SKUs disponibles: 105
# *********************
# Ruta: 1603
# SKUs disponibles: 115
# *********************
# Ruta: 4403
# SKUs disponibles: 121
# *********************
# Ruta: 1406
# SKUs disponibles: 114
# *********************
# Ruta: 3711
# SKUs disponibles: 110
# *********************
# Ruta: 1106
# SKUs disponibles: 108
# *********************
# Ruta: 3203
# SKUs disponibles: 111
# *********************
# Ruta: 5717
# SKUs disponibles: 107
# *********************
# Ruta: 3717
# SKUs disponibles: 107
# *********************
# Ruta: 1109
# SKUs disponibles: 109
# *********************
# Ruta: 1503
# SKUs disponibles: 108
# *********************
# Ruta: 2117
# SKUs disponibles: 98
# *********************
# Ruta: 2507
# SKUs disponibles: 103
# *********************
# Ruta: 3817
# SKUs disponibles: 107
# *********************
# Ruta: 3006
# SKUs disponibles: 119
# *********************
# Ruta: 4817
# SKUs disponibles: 111
# *********************
# Ruta: 3317
# SKUs disponibles: 105
# *********************
# Ruta: 2603
# SKUs disponibles: 106
# *********************
# Ruta: 2808
# SKUs disponibles: 112
# *********************
# Ruta: 2506
# SKUs disponibles: 100
# *********************
# Ruta: 1903
# SKUs disponibles: 101
# *********************
# Ruta: 3417
# SKUs disponibles: 107
# *********************
# Ruta: 3017
# SKUs disponibles: 104
# *********************
# Ruta: 2903
# SKUs disponibles: 119
# *********************
# Ruta: 3103
# SKUs disponibles: 99
# *********************
# Ruta: 3617
# SKUs disponibles: 100
# *********************
# Ruta: 1017
# SKUs disponibles: 102
# *********************
# Ruta: 2317
# SKUs disponibles: 107
# *********************
# Ruta: 2217
# SKUs disponibles: 108
# *********************
# Ruta: 5517
# SKUs disponibles: 106
# *********************
# Ruta: 5617
# SKUs disponibles: 99
# *********************
# Ruta: 3307
# SKUs disponibles: 66
# *********************
# Ruta: 3107
# SKUs disponibles: 23

# %% [markdown]
# **Para rutas que tengan menos de 45 SKUS**

# %%
print("*" * 21)
print("Rutas:", low_sku_ruta)
temp = df_ventas[(df_ventas["cod_ruta"].isin(low_sku_ruta))]
print("SKUs disponibles:", temp["cod_articulo_magic"].nunique())
# print(f"Giros en ruta {ruta}:")
# print(temp.groupby(["desc_giro"])["id_cliente"].nunique(dropna=False))
temp.to_csv("Processed/rutas/D_low_ruta_ventas.csv", index=False)
# Out:
# *********************
# Rutas: []
# SKUs disponibles: 0

# %% [markdown]
# # 4. Modelo Pedido Sugerido

# %% [markdown]
# ## 4.1. Importando librerias necesarias

# %%
import os

from pyspark.sql import SparkSession, SQLContext
from pyspark.sql.types import StructType, StringType, DoubleType, IntegerType
from pyspark.sql.functions import (
    when,
    col,
    regexp_replace,
    concat,
    countDistinct,
    lit,
    monotonically_increasing_id,
    hash,
)

from pyspark.ml.linalg import Vector
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator

from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %%
# !java -version
# Out:
# openjdk version "11.0.30" 2026-01-20 LTS
# OpenJDK Runtime Environment Corretto-11.0.30.7.1 (build 11.0.30+7-LTS)
# OpenJDK 64-Bit Server VM Corretto-11.0.30.7.1 (build 11.0.30+7-LTS, mixed mode)

# %%
import os
# os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk"
os.environ["PATH"] = os.environ["JAVA_HOME"] + "/bin:" + os.environ["PATH"]

# %% [markdown]
# ## 4.2 Construccion del algoritmo ALS

# %%
def als_training_job(cedi, sku_len):

    spark = (
        SparkSession.builder.config("spark.memory.offHeap.enabled", "true")
        .config("spark.memory.offHeap.size", "10G")
        .appName("K-Means for ALS")
        .getOrCreate()
    )

    ventas = (
        spark.read.format("csv")
        .options(header=True, delimiter=",")
        .load(f"Processed/rutas/D_{cedi}_ventas.csv")
    )

    ventas = ventas.na.drop(subset=["fecha_liquidacion"])
    ventas = ventas.groupBy(
        ["id_cliente", "cod_articulo_magic", "cod_compania", "cod_cliente"]
    ).agg(countDistinct("fecha_liquidacion"))
    ventas = ventas.select(
        col("id_cliente").alias("id_cliente"),
        col("count(fecha_liquidacion)").alias("frecuencia"),
        col("cod_articulo_magic").alias("cod_articulo_magic"),
        col("cod_compania").alias("cod_compania"),
        col("cod_cliente").alias("cod_cliente"),
    )

    input_cols = ["frecuencia"]
    vec_assembler = VectorAssembler(inputCols=input_cols, outputCol="features")
    ventas_kmeans = vec_assembler.transform(ventas)
    ventas_kmeans = ventas_kmeans.fillna(0.0, subset=["frecuencia"])

    kmeans = KMeans(featuresCol="features", k=5)
    model = kmeans.fit(ventas_kmeans)

    resumen_ventas = model.transform(ventas_kmeans).groupby("prediction").max()
    resumen_ventas.orderBy(["max(frecuencia)"], ascending=0)
    resumen_ventas = resumen_ventas.select(
        col("prediction").alias("prediction"), col("max(frecuencia)").alias("max")
    )

    maxes = resumen_ventas.select("max").toPandas()["max"]
    maxes = maxes.astype(float)
    maxes = list(maxes)

    labels = [5, 4, 3, 2, 1]
    rank_map = dict(zip(labels, maxes))

    ventas = ventas.withColumn("frecuencia", col("frecuencia").cast(DoubleType()))
    ventas = ventas.withColumn(
        "rating",
        when(ventas["frecuencia"] < rank_map.get(labels[-1]), labels[-1])
        .when(ventas["frecuencia"] < rank_map.get(labels[-2]), labels[-2])
        .when(ventas["frecuencia"] < rank_map.get(labels[-3]), labels[-3])
        .when(ventas["frecuencia"] < rank_map.get(labels[-4]), labels[-4])
        .otherwise(labels[-5]),
    )

    cols = ["id_cliente", "cod_compania", "cod_cliente", "cod_articulo_magic", "rating"]
    als_records = ventas.select(*cols)

    # als_records = als_records.withColumn("clienteId",concat("cod_compania","cod_cliente"))
    als_records = als_records.withColumn(
        "clienteId", concat(col("cod_compania"), lit("|"), col("cod_cliente"))
    )
    # als_records = als_records.withColumn("clienteId", col("clienteId").cast(IntegerType()))
    # Crear una columna numérica para usar en el modelo ALS
    # als_records = als_records.withColumn("clienteId_numeric", monotonically_increasing_id())
    als_records = als_records.withColumn("clienteId_numeric", hash(col("clienteId")))
    als_records = als_records.withColumn(
        "cod_articulo_magic", col("cod_articulo_magic").cast(IntegerType())
    )

    als_records = als_records.na.drop(
        subset=["clienteId_numeric", "cod_articulo_magic"]
    )

    input_cols = ["clienteId", "clienteId_numeric", "cod_articulo_magic", "rating"]
    als_records = als_records.select(*input_cols)

    als_records = als_records.dropDuplicates(["clienteId", "cod_articulo_magic"])

    als = ALS(
        rank=10,
        maxIter=5,
        implicitPrefs=True,
        ratingCol="rating",
        itemCol="cod_articulo_magic",
        userCol="clienteId_numeric",
    )
    model = als.fit(als_records)

    # obtener matrices de descomposicion (usuario y articulos)
    user_matrix = model.userFactors
    item_matrix = model.itemFactors

    user_matrix_pd = user_matrix.toPandas()
    item_matrix_pd = item_matrix.toPandas()

    recs = model.recommendForAllUsers(sku_len)
    # recs = recs.select("ClienteId","recommendations.cod_articulo_magic")
    # recs_to_parse = recs.toPandas()

    recs = recs.select("clienteId_numeric", "recommendations.cod_articulo_magic")
    # Hacer un join con als_records para recuperar la columna 'clienteId' original
    recs = recs.join(
        als_records.select("clienteId", "clienteId_numeric"),
        on="clienteId_numeric",
        how="left",
    )

    # Convertir a pandas
    recs_to_parse = recs.select("clienteId", "cod_articulo_magic").toPandas()

    lista_rec = [f"r{i+1}" for i in range(sku_len)]
    # recs_to_parse[lista_rec] = pd.DataFrame(recs_to_parse['cod_articulo_magic'].tolist(), index= recs_to_parse.index)
    new_cols = pd.DataFrame(
        recs_to_parse["cod_articulo_magic"].tolist(),
        index=recs_to_parse.index,
        columns=lista_rec,
    )
    recs_to_parse = pd.concat([recs_to_parse, new_cols], axis=1)
    client_recs = pd.melt(
        recs_to_parse, id_vars=["clienteId"], value_vars=lista_rec
    )

    # client_recs['compania'] = client_recs["clienteId"].apply(lambda x: str(x)[:2])
    client_recs["compania"] = client_recs["clienteId"].str.split("|").str[-2]
    # client_recs['cliente'] = client_recs["clienteId"].apply(lambda x: str(x)[2:])
    #client_recs["cliente"] = client_recs["clienteId"].str.split("|").str[1].apply(lambda x: str(x)[:])
    client_recs["cliente"] = client_recs["clienteId"].str.split("|").str[-1]
    client_recs["compania"] = client_recs["compania"].apply(lambda x: x.rjust(4, "0"))
    client_recs["id_cliente"] = client_recs["compania"] + "|" + client_recs["cliente"]
    client_recs["cod_articulo_magic"] = client_recs["value"]
    
    # print(client_recs)

    client_recs = (
        client_recs[["id_cliente", "cod_articulo_magic"]]
        .drop_duplicates()
        .reset_index(drop=True)
    )

    # Obtener el nombre del archivo CSV
    nombre_archivo = "Output/D_rutas_rec.csv"
    # Verificar si el archivo ya existe
    try:
        # Intentar abrir el archivo para lectura
        with open(nombre_archivo, "r") as f:
            # Si el archivo existe, header=False para no escribir cabeceras
            client_recs.to_csv(
                nombre_archivo, mode="a", header=False, index=False, sep=";"
            )
    except FileNotFoundError:
        # Si el archivo no existe, header=True para escribir las cabeceras
        client_recs.to_csv(nombre_archivo, mode="a", header=True, index=False, sep=";")

# %% [markdown]
# ## 4.3 Corriendo PS

# %%
def runALS():
    # Ruta del archivo que deseas verificar y eliminar si existe
    ruta_archivo = "Output/D_rutas_rec.csv"
    # Verificar si el archivo existe
    if os.path.exists(ruta_archivo):
        # Eliminar el archivo si existe
        os.remove(ruta_archivo)
        print(f"El archivo en la ruta {ruta_archivo} ha sido eliminado.")
    else:
        print(f"El archivo en la ruta {ruta_archivo} no existe.")
    # CORRIENDO ALS PARA RUTAS DE MAS DE 45 SKUs
    for ruta in rutas:
        print("*" * 21)
        temp = pd.read_csv(f"Processed/rutas/D_{ruta}_ventas.csv")
        sku_len = temp["cod_articulo_magic"].nunique()
        print(f"SKUs disponibles en ruta {ruta}:", sku_len)
        als_training_job(ruta, sku_len)
    # CORRIENDO ALS PARA rutas que tengan menos de 45 SKUS
    if len(low_sku_ruta) != 0:
        temp = pd.read_csv(f"Processed/rutas/D_low_ruta_ventas.csv")
        sku_len = temp["cod_articulo_magic"].nunique()
        print(f"SKUs disponibles en low ruta {low_sku_ruta}:", sku_len)
        als_training_job("low_ruta", sku_len)
    else:
        print("No existen rutas con pocos skus :D")

# %%
rutas = rutas[~pd.Series(rutas).isin(pd.Series(low_sku_ruta))]
rutas
# Out:
# array([3411, 4217, 5404, 3304, 4903, 4504, 2706, 3303, 5204, 1309, 2717,
#        2904, 2804, 3403, 3811, 1217, 1917, 1904, 4517, 4604, 3504, 4711,
#        5703, 2011, 3211, 1417, 2107, 4704, 2809, 4804, 1211, 2307, 2411,
#        5104, 2504, 2209, 1911, 1706, 2106, 2111, 3117, 1704, 3611, 4904,
#        1403, 1104, 4617, 1108, 3104, 2911, 3517, 2008, 3011, 3204, 1517,
#        5603, 2404, 2304, 2417, 3806, 1607, 2311, 2406, 1906, 2204, 2611,
#        2704, 3111, 3004, 2009, 1504, 1308, 1011, 1609, 1804, 2306, 3911,
#        1809, 2709, 1408, 2211, 2604, 1304, 1204, 3404, 2517, 3511, 1409,
#        2711, 2407, 1808, 1608, 1806, 4017, 1604, 2109, 1807, 2207, 2811,
#        3106, 2208, 2006, 3217, 4917, 1506, 1907, 3311, 1306, 1208, 1511,
#        2206, 1206, 1404, 3917, 1717, 3507, 2108, 1103, 1611, 1711, 4811,
#        2004, 2104, 2003, 1311, 2511, 1209, 2617, 1411, 2807, 2817, 4117,
#        2703, 1009, 1008, 1004, 1909, 1709, 1908, 2917, 2303, 2806, 4317,
#        4011, 2606, 2403, 2607, 1606, 1006, 1817, 3607, 1811, 4106, 1803,
#        1617, 1117, 2017, 2707, 1317, 4417, 3003, 2203, 2408, 1107, 1407,
#        1003, 1203, 3604, 2803, 1307, 1507, 2007, 2906, 2609, 1207, 2503,
#        2103, 1303, 5203, 1703, 1708, 4703, 4717, 1007, 1603, 4403, 1406,
#        3711, 1106, 3203, 5717, 3717, 1109, 1503, 2117, 2507, 3817, 3006,
#        4817, 3317, 2603, 2808, 2506, 1903, 3417, 3017, 2903, 3103, 3617,
#        1017, 2317, 2217, 5517, 5617, 3307, 3107])

# %%
# %%time
runALS()
# Out:
# El archivo en la ruta Output/D_rutas_rec.csv ha sido eliminado.
# *********************
# SKUs disponibles en ruta 3411: 108
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/30 20:30:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/03/30 20:31:04 WARN InstanceBuilder$NativeBLAS: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 26/03/30 20:31:04 WARN InstanceBuilder$NativeBLAS: Failed to load implementation from:dev.ludovic.netlib.blas.ForeignLinkerBLAS
# 26/03/30 20:31:05 WARN InstanceBuilder$NativeLAPACK: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK
# *********************
# SKUs disponibles en ruta 4217: 110
# *********************
# SKUs disponibles en ruta 5404: 112
# *********************
# SKUs disponibles en ruta 3304: 119
# *********************
# SKUs disponibles en ruta 4903: 112
# *********************
# SKUs disponibles en ruta 4504: 109
# *********************
# SKUs disponibles en ruta 2706: 120
# *********************
# SKUs disponibles en ruta 3303: 126
# *********************
# SKUs disponibles en ruta 5204: 113
# *********************
# SKUs disponibles en ruta 1309: 109
# *********************
# SKUs disponibles en ruta 2717: 104
# *********************
# SKUs disponibles en ruta 2904: 113
# *********************
# SKUs disponibles en ruta 2804: 116
# *********************
# SKUs disponibles en ruta 3403: 114
# *********************
# SKUs disponibles en ruta 3811: 106
# *********************
# SKUs disponibles en ruta 1217: 99
# *********************
# SKUs disponibles en ruta 1917: 105
# *********************
# SKUs disponibles en ruta 1904: 119
# *********************
# SKUs disponibles en ruta 4517: 106
# *********************
# SKUs disponibles en ruta 4604: 107
# *********************
# SKUs disponibles en ruta 3504: 117
# *********************
# SKUs disponibles en ruta 4711: 107
# *********************
# SKUs disponibles en ruta 5703: 104
# *********************
# SKUs disponibles en ruta 2011: 106
# *********************
# SKUs disponibles en ruta 3211: 102
# *********************
# SKUs disponibles en ruta 1417: 103
# *********************
# SKUs disponibles en ruta 2107: 114
# *********************
# SKUs disponibles en ruta 4704: 100
# *********************
# SKUs disponibles en ruta 2809: 102
# *********************
# SKUs disponibles en ruta 4804: 113
# *********************
# SKUs disponibles en ruta 1211: 108
# *********************
# SKUs disponibles en ruta 2307: 111
# *********************
# SKUs disponibles en ruta 2411: 99
# *********************
# SKUs disponibles en ruta 5104: 105
# *********************
# SKUs disponibles en ruta 2504: 124
# *********************
# SKUs disponibles en ruta 2209: 115
# *********************
# SKUs disponibles en ruta 1911: 108
# *********************
# SKUs disponibles en ruta 1706: 116
# *********************
# SKUs disponibles en ruta 2106: 114
# *********************
# SKUs disponibles en ruta 2111: 103
# *********************
# SKUs disponibles en ruta 3117: 100
# *********************
# SKUs disponibles en ruta 1704: 119
# *********************
# SKUs disponibles en ruta 3611: 104
# *********************
# SKUs disponibles en ruta 4904: 114
# *********************
# SKUs disponibles en ruta 1403: 111
# *********************
# SKUs disponibles en ruta 1104: 111
# *********************
# SKUs disponibles en ruta 4617: 107
# *********************
# SKUs disponibles en ruta 1108: 110
# *********************
# SKUs disponibles en ruta 3104: 115
# *********************
# SKUs disponibles en ruta 2911: 102
# *********************
# SKUs disponibles en ruta 3517: 117
# *********************
# SKUs disponibles en ruta 2008: 111
# *********************
# SKUs disponibles en ruta 3011: 107
# *********************
# SKUs disponibles en ruta 3204: 115
# *********************
# SKUs disponibles en ruta 1517: 108
# *********************
# SKUs disponibles en ruta 5603: 110
# *********************
# SKUs disponibles en ruta 2404: 113
# *********************
# SKUs disponibles en ruta 2304: 105
# *********************
# SKUs disponibles en ruta 2417: 110
# *********************
# SKUs disponibles en ruta 3806: 121
# *********************
# SKUs disponibles en ruta 1607: 112
# *********************
# SKUs disponibles en ruta 2311: 105
# *********************
# SKUs disponibles en ruta 2406: 117
# *********************
# SKUs disponibles en ruta 1906: 112
# *********************
# SKUs disponibles en ruta 2204: 107
# *********************
# SKUs disponibles en ruta 2611: 107
# *********************
# SKUs disponibles en ruta 2704: 108
# *********************
# SKUs disponibles en ruta 3111: 110
# *********************
# SKUs disponibles en ruta 3004: 121
# *********************
# SKUs disponibles en ruta 2009: 108
# *********************
# SKUs disponibles en ruta 1504: 115
# *********************
# SKUs disponibles en ruta 1308: 107
# *********************
# SKUs disponibles en ruta 1011: 108
# *********************
# SKUs disponibles en ruta 1609: 105
# *********************
# SKUs disponibles en ruta 1804: 116
# *********************
# SKUs disponibles en ruta 2306: 111
# *********************
# SKUs disponibles en ruta 3911: 103
# *********************
# SKUs disponibles en ruta 1809: 109
# *********************
# SKUs disponibles en ruta 2709: 107
# *********************
# SKUs disponibles en ruta 1408: 105
# *********************
# SKUs disponibles en ruta 2211: 108
# *********************
# SKUs disponibles en ruta 2604: 112
# *********************
# SKUs disponibles en ruta 1304: 119
# *********************
# SKUs disponibles en ruta 1204: 111
# *********************
# SKUs disponibles en ruta 3404: 115
# *********************
# SKUs disponibles en ruta 2517: 96
# *********************
# SKUs disponibles en ruta 3511: 109
# *********************
# SKUs disponibles en ruta 1409: 108
# *********************
# SKUs disponibles en ruta 2711: 111
# *********************
# SKUs disponibles en ruta 2407: 106
# *********************
# SKUs disponibles en ruta 1808: 103
# *********************
# SKUs disponibles en ruta 1608: 107
# *********************
# SKUs disponibles en ruta 1806: 114
# *********************
# SKUs disponibles en ruta 4017: 112
# *********************
# SKUs disponibles en ruta 1604: 106
# *********************
# SKUs disponibles en ruta 2109: 108
# *********************
# SKUs disponibles en ruta 1807: 106
# *********************
# SKUs disponibles en ruta 2207: 98
# *********************
# SKUs disponibles en ruta 2811: 107
# *********************
# SKUs disponibles en ruta 3106: 124
# *********************
# SKUs disponibles en ruta 2208: 106
# *********************
# SKUs disponibles en ruta 2006: 114
# *********************
# SKUs disponibles en ruta 3217: 101
# *********************
# SKUs disponibles en ruta 4917: 110
# *********************
# SKUs disponibles en ruta 1506: 116
# *********************
# SKUs disponibles en ruta 1907: 106
# *********************
# SKUs disponibles en ruta 3311: 107
# *********************
# SKUs disponibles en ruta 1306: 118
# *********************
# SKUs disponibles en ruta 1208: 104
# *********************
# SKUs disponibles en ruta 1511: 101
# *********************
# SKUs disponibles en ruta 2206: 115
# *********************
# SKUs disponibles en ruta 1206: 114
# *********************
# SKUs disponibles en ruta 1404: 120
# *********************
# SKUs disponibles en ruta 3917: 111
# *********************
# SKUs disponibles en ruta 1717: 101
# *********************
# SKUs disponibles en ruta 3507: 104
# *********************
# SKUs disponibles en ruta 2108: 109
# *********************
# SKUs disponibles en ruta 1103: 112
# *********************
# SKUs disponibles en ruta 1611: 109
# *********************
# SKUs disponibles en ruta 1711: 99
# *********************
# SKUs disponibles en ruta 4811: 107
# *********************
# SKUs disponibles en ruta 2004: 114
# *********************
# SKUs disponibles en ruta 2104: 104
# *********************
# SKUs disponibles en ruta 2003: 107
# *********************
# SKUs disponibles en ruta 1311: 110
# *********************
# SKUs disponibles en ruta 2511: 101
# *********************
# SKUs disponibles en ruta 1209: 105
# *********************
# SKUs disponibles en ruta 2617: 101
# *********************
# SKUs disponibles en ruta 1411: 104
# *********************
# SKUs disponibles en ruta 2807: 105
# *********************
# SKUs disponibles en ruta 2817: 117
# *********************
# SKUs disponibles en ruta 4117: 99
# *********************
# SKUs disponibles en ruta 2703: 111
# *********************
# SKUs disponibles en ruta 1009: 105
# *********************
# SKUs disponibles en ruta 1008: 114
# *********************
# SKUs disponibles en ruta 1004: 105
# *********************
# SKUs disponibles en ruta 1909: 97
# *********************
# SKUs disponibles en ruta 1709: 109
# *********************
# SKUs disponibles en ruta 1908: 108
# *********************
# SKUs disponibles en ruta 2917: 108
# *********************
# SKUs disponibles en ruta 2303: 91
# *********************
# SKUs disponibles en ruta 2806: 110
# *********************
# SKUs disponibles en ruta 4317: 106
# *********************
# SKUs disponibles en ruta 4011: 109
# *********************
# SKUs disponibles en ruta 2606: 121
# *********************
# SKUs disponibles en ruta 2403: 120
# *********************
# SKUs disponibles en ruta 2607: 104
# *********************
# SKUs disponibles en ruta 1606: 112
# *********************
# SKUs disponibles en ruta 1006: 118
# *********************
# SKUs disponibles en ruta 1817: 112
# *********************
# SKUs disponibles en ruta 3607: 109
# *********************
# SKUs disponibles en ruta 1811: 110
# *********************
# SKUs disponibles en ruta 4106: 119
# *********************
# SKUs disponibles en ruta 1803: 116
# *********************
# SKUs disponibles en ruta 1617: 109
# *********************
# SKUs disponibles en ruta 1117: 107
# *********************
# SKUs disponibles en ruta 2017: 108
# *********************
# SKUs disponibles en ruta 2707: 97
# *********************
# SKUs disponibles en ruta 1317: 100
# *********************
# SKUs disponibles en ruta 4417: 109
# *********************
# SKUs disponibles en ruta 3003: 113
# *********************
# SKUs disponibles en ruta 2203: 111
# *********************
# SKUs disponibles en ruta 2408: 112
# *********************
# SKUs disponibles en ruta 1107: 94
# *********************
# SKUs disponibles en ruta 1407: 103
# *********************
# SKUs disponibles en ruta 1003: 114
# *********************
# SKUs disponibles en ruta 1203: 114
# *********************
# SKUs disponibles en ruta 3604: 121
# *********************
# SKUs disponibles en ruta 2803: 117
# *********************
# SKUs disponibles en ruta 1307: 104
# *********************
# SKUs disponibles en ruta 1507: 105
# *********************
# SKUs disponibles en ruta 2007: 103
# *********************
# SKUs disponibles en ruta 2906: 111
# *********************
# SKUs disponibles en ruta 2609: 99
# *********************
# SKUs disponibles en ruta 1207: 104
# *********************
# SKUs disponibles en ruta 2503: 113
# *********************
# SKUs disponibles en ruta 2103: 111
# *********************
# SKUs disponibles en ruta 1303: 113
# *********************
# SKUs disponibles en ruta 5203: 110
# *********************
# SKUs disponibles en ruta 1703: 119
# *********************
# SKUs disponibles en ruta 1708: 112
# *********************
# SKUs disponibles en ruta 4703: 103
# *********************
# SKUs disponibles en ruta 4717: 104
# *********************
# SKUs disponibles en ruta 1007: 105
# *********************
# SKUs disponibles en ruta 1603: 115
# *********************
# SKUs disponibles en ruta 4403: 121
# *********************
# SKUs disponibles en ruta 1406: 114
# *********************
# SKUs disponibles en ruta 3711: 110
# *********************
# SKUs disponibles en ruta 1106: 108
# *********************
# SKUs disponibles en ruta 3203: 111
# *********************
# SKUs disponibles en ruta 5717: 107
# *********************
# SKUs disponibles en ruta 3717: 107
# *********************
# SKUs disponibles en ruta 1109: 109
# *********************
# SKUs disponibles en ruta 1503: 108
# *********************
# SKUs disponibles en ruta 2117: 98
# *********************
# SKUs disponibles en ruta 2507: 103
# *********************
# SKUs disponibles en ruta 3817: 107
# *********************
# SKUs disponibles en ruta 3006: 119
# *********************
# SKUs disponibles en ruta 4817: 111
# *********************
# SKUs disponibles en ruta 3317: 105
# *********************
# SKUs disponibles en ruta 2603: 106
# *********************
# SKUs disponibles en ruta 2808: 112
# *********************
# SKUs disponibles en ruta 2506: 100
# *********************
# SKUs disponibles en ruta 1903: 101
# *********************
# SKUs disponibles en ruta 3417: 107
# *********************
# SKUs disponibles en ruta 3017: 104
# *********************
# SKUs disponibles en ruta 2903: 119
# *********************
# SKUs disponibles en ruta 3103: 99
# *********************
# SKUs disponibles en ruta 3617: 100
# *********************
# SKUs disponibles en ruta 1017: 102
# *********************
# SKUs disponibles en ruta 2317: 107
# *********************
# SKUs disponibles en ruta 2217: 108
# *********************
# SKUs disponibles en ruta 5517: 106
# *********************
# SKUs disponibles en ruta 5617: 99
# *********************
# SKUs disponibles en ruta 3307: 66
# *********************
# SKUs disponibles en ruta 3107: 23
# No existen rutas con pocos skus :D
# CPU times: user 4min 53s, sys: 3.64 s, total: 4min 56s
# Wall time: 16min 37s

# %% [markdown]
# # 5. Ajustes al output del algoritmo ALS

# %% [markdown]
# ## 5.-9 Quedarnos con skus que hayan tenido ventas en los ultimos 30 dias

# %%
pan_rec = pd.read_csv("Output/D_rutas_rec.csv", sep=";")
pan_rec["id_cliente"] = "EC|" + pan_rec["id_cliente"]

# %%
pan_rec = pd.merge(pan_rec,pan_ventas[["id_cliente","cod_ruta"]].drop_duplicates(),on="id_cliente",how="left")

# %%
pan_rec
# Out:
#              id_cliente  cod_articulo_magic  cod_ruta
# 0        EC|0090|478165              523104      3411
# 1         EC|0090|48450              508586      3411
# 2        EC|0090|240506              523108      3411
# 3        EC|0090|483904              511920      3411
# 4         EC|0090|67099              523079      3411
# ...                 ...                 ...       ...
# 2026381  EC|0090|484405              800074      3107
# 2026382  EC|0090|484917              514445      3107
# 2026383  EC|0090|483898              800075      3107
# 2026384  EC|0090|484405              800075      3107
# 2026385  EC|0090|484917              598949      3107
#
# [2026386 rows x 3 columns]

# %%
pan_rec.id_cliente.nunique()
# Out:
# 18578

# %%
# %%time
df_ventas = pd.read_parquet("Processed/ecuador_ventas_manana.parquet")
# Out:
# CPU times: user 4.93 s, sys: 1.82 s, total: 6.76 s
# Wall time: 2.52 s

# %%
df_ventas["fecha_liquidacion"] = pd.to_datetime(df_ventas["fecha_liquidacion"])

# %%
# Definir el umbral de tiempo (últimos 30 días desde hoy)
# bajamos de 30 a 14 dias 2025-07-25
hoy = pd.Timestamp.today()
fecha_limite = hoy - pd.Timedelta(days=14)
print(fecha_limite)
# Filtrar ventas en los últimos 30 días
ventas_filtradas = df_ventas[df_ventas["fecha_liquidacion"] >= fecha_limite]
# Out:
# 2026-03-16 20:47:22.221125

# %%
# Obtener los productos vendidos en cada ruta
productos_por_ruta = ventas_filtradas.groupby("cod_ruta")["cod_articulo_magic"].unique().reset_index()

# %%
# Unir con los productos vendidos en cada ruta
recomendaciones_validas = pan_rec.merge(productos_por_ruta, on="cod_ruta", how="inner")

# %%
recomendaciones_validas.columns = ['id_cliente', 'cod_articulo_magic', 'cod_ruta','lista_sku_ruta']

# %%
recomendaciones_validas.shape
# Out:
# (2026386, 4)

# %%
recomendaciones_validas  = recomendaciones_validas[recomendaciones_validas.apply(lambda row: row["cod_articulo_magic"] in row["lista_sku_ruta"], axis=1)].reset_index(drop=True)

# %%
recomendaciones_validas.shape
# Out:
# (1106129, 4)

# %%
recomendaciones_validas.head()
# Out:
#        id_cliente  cod_articulo_magic  cod_ruta  \
# 0  EC|0090|478165              523104      3411
# 1   EC|0090|48450              508586      3411
# 2  EC|0090|240506              523108      3411
# 3  EC|0090|483904              511920      3411
# 4   EC|0090|67099              523079      3411
#
#                                       lista_sku_ruta
# 0  [509545, 508586, 524188, 523075, 524189, 51726...
# 1  [509545, 508586, 524188, 523075, 524189, 51726...
# 2  [509545, 508586, 524188, 523075, 524189, 51726...
# 3  [509545, 508586, 524188, 523075, 524189, 51726...
# 4  [509545, 508586, 524188, 523075, 524189, 51726...

# %%
pan_rec = recomendaciones_validas[["id_cliente","cod_articulo_magic"]].reset_index(drop=True)

# %%
pan_rec.head()
# Out:
#        id_cliente  cod_articulo_magic
# 0  EC|0090|478165              523104
# 1   EC|0090|48450              508586
# 2  EC|0090|240506              523108
# 3  EC|0090|483904              511920
# 4   EC|0090|67099              523079

# %%
pan_rec.shape
# Out:
# (1106129, 2)

# %%
pan_rec.to_csv("Output/D_rutas_rec.csv", sep=";", index=False)

# %% [markdown]
# ## 5.-8 Recomendar de acuerdo a Subida, Bajada, Mantener

# %%
pan_rec = pd.read_csv("Output/D_rutas_rec.csv", sep=";")
#pan_rec["id_cliente"] = "EC|" + pan_rec["id_cliente"]

# %%
pan_rec.shape
# Out:
# (1106129, 2)

# %%
pan_rec = pd.merge(pan_rec,pan_ventas[["id_cliente","cod_ruta"]].drop_duplicates(),on="id_cliente",how="left")

# %%
# df_ventas = pd.read_csv("Processed/ecuador_ventas_manana.csv")

# %%
def desplazar_nulos_fila(fila):
    return pd.Series(sorted(fila, key=pd.isna), index=fila.index)

# %%
# Definir una función para asignar los valores subida, mantener y bajar
def clasificar_valor(x):
    if x > 0:
        return "S"
    elif x == 0:
        return "M"
    else:
        return "B"

# %%
# df_ventas['fecha_liquidacion'] = pd.to_datetime(df_ventas['fecha_liquidacion'])

# Definir la fecha de referencia (hoy)
fecha_actual = datetime.now(pytz.timezone("America/Lima"))#.strftime('%Y-%m-%d')
fecha_30dias_atras = (fecha_actual - pd.Timedelta(days=30)).strftime('%Y-%m-%d')
fecha_60dias_atras = (fecha_actual - pd.Timedelta(days=60)).strftime('%Y-%m-%d')

print("fecha_actual",fecha_actual)
print("fecha_30dias_atras",fecha_30dias_atras)
print("fecha_60dias_atras",fecha_60dias_atras)
# Out:
# fecha_actual 2026-03-30 15:47:46.860127-05:00
# fecha_30dias_atras 2026-02-28
# fecha_60dias_atras 2026-01-29

# %%
# Filtrar los últimos 30 días
df_ultimos_30 = df_ventas[(df_ventas['fecha_liquidacion'] > fecha_30dias_atras) 
                          & (df_ventas['fecha_liquidacion'] <= fecha_actual.strftime('%Y-%m-%d'))]

# Filtrar los días 31 a 60
df_31_60 = df_ventas[(df_ventas['fecha_liquidacion'] > fecha_60dias_atras)
              & (df_ventas['fecha_liquidacion'] <= fecha_30dias_atras)]

# Agrupar por codigo_usuario, ruta, codigo_producto y sumar ventas
ventas_ultimos_30 = df_ultimos_30.groupby(['cod_ruta', 'cod_articulo_magic'])['imp_netovta'].sum().reset_index()
ventas_ultimos_30["mes"] = "0_30"
ventas_31_60 = df_31_60.groupby(['cod_ruta', 'cod_articulo_magic'])['imp_netovta'].sum().reset_index()
ventas_31_60["mes"] = "31_60"

df_grouped = pd.concat([ventas_ultimos_30,ventas_31_60],axis=0,ignore_index=True)
df_grouped = pd.pivot_table(
    df_grouped,
    values="imp_netovta",
    index=["cod_ruta", "cod_articulo_magic"],
    columns=["mes"],
    aggfunc="sum",
).reset_index()

# Rellenando con 0 si es nulo
df_grouped["0_30"] = df_grouped["0_30"].fillna(0)
df_grouped["31_60"] = df_grouped["31_60"].fillna(0)

# Asignando variacion de productos por mes
df_grouped["v1_2"] = (
    (df_grouped[df_grouped.columns[2]] - df_grouped[df_grouped.columns[3]])
    / df_grouped[df_grouped.columns[3]]
    * 100
)
df_grouped["v1_2"].replace([float('inf'), float('-inf')], -1, inplace=True)
df_grouped["v1_2"] = df_grouped["v1_2"].fillna(-1)
df_grouped["vp"] = (df_grouped["v1_2"])
# Out:
# /tmp/ipykernel_31118/261865676.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_grouped["v1_2"].replace([float('inf'), float('-inf')], -1, inplace=True)

# %%
# Aplicar la función a la columna 'valor' y guardar el resultado en una nueva columna 'flag'
df_grouped["flag"] = df_grouped["vp"].apply(lambda x: clasificar_valor(x))
# Definir el mapeo de valores
mapeo_flag = {"S": 0, "M": 1, "B": 2}
# Aplicar el mapeo a la columna 'clasificacion' y guardar el resultado en una nueva columna 'flag_rank'
df_grouped["flag_rank"] = df_grouped["flag"].map(mapeo_flag)

# %%
df_grouped
# Out:
# mes    cod_ruta  cod_articulo_magic      0_30     31_60        v1_2  \
# 0          1003              500010  143.4881  218.4013  -34.300712
# 1          1003              500147  473.7926  595.7294  -20.468488
# 2          1003              500187    5.8472    5.8472    0.000000
# 3          1003              508462  284.0023  280.9151    1.098980
# 4          1003              508514  881.5302  550.9563   60.000022
# ...         ...                 ...       ...       ...         ...
# 16851      5717              624067    0.0000    0.8006 -100.000000
# 16852      5717              699814    0.0000    1.3050 -100.000000
# 16853      5717              800072    0.0000   10.0500 -100.000000
# 16854      5717              800073    3.3500   13.4000  -75.000000
# 16855      5717              800076    0.0000   40.0000 -100.000000
#
# mes            vp flag  flag_rank
# 0      -34.300712    B          2
# 1      -20.468488    B          2
# 2        0.000000    M          1
# 3        1.098980    S          0
# 4       60.000022    S          0
# ...           ...  ...        ...
# 16851 -100.000000    B          2
# 16852 -100.000000    B          2
# 16853 -100.000000    B          2
# 16854  -75.000000    B          2
# 16855 -100.000000    B          2
#
# [16856 rows x 8 columns]

# %%
pan_rec.shape
# Out:
# (1106129, 3)

# %%
pan_rec = pd.merge(pan_rec,df_grouped[["cod_ruta", "cod_articulo_magic","flag_rank"]],on=["cod_ruta", "cod_articulo_magic"],how="left")

# %%
pan_rec["flag_rank"] = pan_rec["flag_rank"].fillna(3)

# %%
# Agregar una columna con el orden original
pan_rec["original_order"] = pan_rec.index

# %%
# Ordenar por cod_cliente, rank_producto (ascendente) y mantener el orden original en caso de empate
pan_rec = pan_rec.sort_values(by=["id_cliente", "flag_rank", "original_order"], ascending=[True, True, True])#.drop(columns=["original_order"])

# %%
pan_rec.head()
# Out:
#            id_cliente  cod_articulo_magic  cod_ruta  flag_rank  original_order
# 619598  EC|0090|10003              515519      4917          0          619598
# 619941  EC|0090|10003              515417      4917          0          619941
# 620027  EC|0090|10003              515408      4917          0          620027
# 620111  EC|0090|10003              508514      4917          0          620111
# 620187  EC|0090|10003              599211      4917          0          620187

# %%
pan_rec.shape
# Out:
# (1106129, 5)

# %%
pan_rec = pan_rec[["id_cliente","cod_articulo_magic"]].reset_index(drop=True)

# %%
pan_rec.head()
# Out:
#       id_cliente  cod_articulo_magic
# 0  EC|0090|10003              515519
# 1  EC|0090|10003              515417
# 2  EC|0090|10003              515408
# 3  EC|0090|10003              508514
# 4  EC|0090|10003              599211

# %%
pan_rec.shape
# Out:
# (1106129, 2)

# %%
pan_rec.to_csv("Output/D_rutas_rec.csv", sep=";", index=False)

# %% [markdown]
# ## 5.-7 Usamos el archivo de validacion para no recomendar SKUs que no se deben a las rutas

# %%
pan_rec = pd.read_csv("Output/D_rutas_rec.csv", sep=";")
# pan_rec["id_cliente"] = "EC|" + pan_rec["id_cliente"]

# %%
pan_rec.shape
# Out:
# (1106129, 2)

# %%
pan_rec = pd.merge(pan_rec,pan_ventas[["id_cliente","cod_ruta"]].drop_duplicates(),on="id_cliente",how="left")

# %%
pan_rec.isnull().sum()
# Out:
# id_cliente            0
# cod_articulo_magic    0
# cod_ruta              0
# dtype: int64

# %%
pan_rec.groupby("cod_ruta").cod_articulo_magic.nunique().head()
# Out:
# cod_ruta
# 1003    70
# 1004    60
# 1006    52
# 1007    66
# 1008    52
# Name: cod_articulo_magic, dtype: int64

# %%
pan_rec.groupby("cod_ruta").cod_articulo_magic.nunique().mean()
# Out:
# 58.75925925925926

# %%
# Ruta del archivo en S3
s3_path = "s3://aje-prd-analytics-artifacts-s3/pedido_sugerido/data-v1/ecuador/maestro_productos_ecuador000"

# Leer el CSV directamente a un DataFrame
skus_val = pd.read_csv(s3_path,sep = ";")
# skus_val = pd.read_csv("maestra_productos_ecuador_20250217.csv",sep=";")
# skus_val.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.12/site-packages/fsspec/registry.py:301: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)

# %%
skus_val = skus_val[skus_val.cod_compania==90]
# Nos quedamos solo con las filas del proceso de hoy
# Obtener la fecha de hoy en el mismo formato
hoy = int(datetime.now(pytz.timezone("America/Lima")).strftime('%Y%m%d'))
print("fecha_proceso: ", hoy)
# Filtrar solo las filas con la fecha de hoy
# skus_val = skus_val[skus_val['fecha_proceso'] == hoy]
skus_val["cod_compania"] = (skus_val["cod_compania"].astype(str).apply(lambda x: str(int(x)).rjust(4, "0")))
skus_val["id_cliente"] = (
    "EC"
    + "|"
    + skus_val["cod_compania"].astype(str)
    + "|"
    + skus_val["cod_cliente"].astype(str)
)
# Out:
# fecha_proceso:  20260330

# %%
skus_val.head()
# Out:
#   cod_compania   desc_compania  cod_sucursal        desc_sucursal  cod_zona  \
# 0         0090  AJECUADOR S.A.            17  CEDIS GUAYAQUIL SUR     90117
# 1         0090  AJECUADOR S.A.             9  CEDIS SANTO DOMINGO     90209
# 2         0090  AJECUADOR S.A.             4    CEDIS QUITO NORTE     90104
# 3         0090  AJECUADOR S.A.            11      CEDIS QUITO SUR     90111
# 4         0090  AJECUADOR S.A.            17  CEDIS GUAYAQUIL SUR     90217
#
#              desc_zona  cod_ruta           desc_ruta  cod_modulo desc_modulo  \
# 0  90117 - TRADICIONAL      1517         TRADICIONAL         145       Ma-Vi
# 1          TRADICIONAL      1109         TRADICIONAL         592       Ma-Vi
# 2  90104 - TRADICIONAL      1004  1004 - TRADICIONAL         405       Lu-Ju
# 3          TRADICIONAL      1211         TRADICIONAL         513       Ma-Vi
# 4  90217 - TRADICIONAL      2417         TRADICIONAL         175       Mi-Sa
#
#    cod_cliente  cod_articulo_magic  \
# 0       365059              599653
# 1       409431              500147
# 2       453592              516810
# 3       487457              509728
# 4       429253              508586
#
#                                        desc_articulo      id_cliente
# 0              BIG COLA PET NO RETORNABLE 1100 ML 12  EC|0090|365059
# 1          BIG COLA PET NO RETORNABLE 2250 ml 6 pack  EC|0090|409431
# 2  SPORADE BLUEBERRY REGULAR PET NO RETORNABLE 12...  EC|0090|453592
# 3  CIFRUT TROPICAL PUNCH PET NO RETORNABLE 1000 M...  EC|0090|487457
# 4            CIELO AGUA PET NO RETORNABLE 1200 ML 12  EC|0090|429253

# %%
skus_val.shape
# Out:
# (1787798, 14)

# %%
# skus_val = pd.read_csv("productos_pedido_sugerido_validacion_cam_090225.csv",sep=";")
# skus_val = skus_val[skus_val.cod_compania==70].reset_index(drop=True)

# %%
# Cada ruta pertenece a una compañia
skus_val.groupby("cod_ruta").cod_compania.nunique().mean()
# Out:
# 1.0

# %%
pan_rec = pd.merge(pan_rec,skus_val[['cod_articulo_magic', 'id_cliente']].drop_duplicates(),left_on=["id_cliente","cod_articulo_magic"],right_on=["id_cliente","cod_articulo_magic"],how="inner")

# %%
pan_rec.shape
# Out:
# (497912, 3)

# %%
pan_rec.groupby("cod_ruta").cod_articulo_magic.nunique().head()
# Out:
# cod_ruta
# 1003    70
# 1004    60
# 1006    52
# 1007    66
# 1008    52
# Name: cod_articulo_magic, dtype: int64

# %%
pan_rec.groupby("cod_ruta").cod_articulo_magic.nunique().mean()
# Out:
# 58.75925925925926

# %%
pan_rec.groupby("id_cliente").cod_articulo_magic.nunique().mean()
# Out:
# 26.812708669897685

# %%
pan_rec.id_cliente.nunique()
# Out:
# 18570

# %%
pan_rec = pan_rec[["id_cliente","cod_articulo_magic"]]

# %%
pan_rec.head()
# Out:
#       id_cliente  cod_articulo_magic
# 0  EC|0090|10003              515519
# 1  EC|0090|10003              515417
# 2  EC|0090|10003              515408
# 3  EC|0090|10003              508514
# 4  EC|0090|10003              599211

# %%
pan_rec.shape
# Out:
# (497912, 2)

# %%
pan_rec.to_csv("Output/D_rutas_rec.csv", sep=";", index=False)

# %% [markdown]
# ## 5.-5 Cruzar recomendaciones con df_quiebres (STOCK)

# %% [markdown]
# ## 5.-5 Filtrar SKUs por STOCK

# %%
stock = pd.read_csv("s3://aje-prd-analytics-artifacts-s3/pedido_sugerido/data-v1/ecuador/D_stock_ec.csv")

# %%
stock.drop(columns=["Fecha","Database"], inplace=True)
stock.columns=["cod_compania","cod_sucursal","cod_articulo_magic","stock_cf"]

# %%
stock["cod_compania"] = (stock["cod_compania"].astype(str).apply(lambda x: str(int(x)).rjust(4, "0")))
stock["cod_sucursal"] = (stock["cod_sucursal"].astype(str).apply(lambda x: str(int(x)).rjust(2, "0")))

# %%
fecha_hace_12_dias = (datetime.today() - timedelta(days=12)).strftime('%Y-%m-%d')
print(fecha_hace_12_dias)
# Out:
# 2026-03-18

# %%
# Promedio diario de cajas fisicas por sucursal y compañia de los ultimos 12 dias
prom_diario_vta = df_ventas[df_ventas.cant_cajafisicavta > 0]
prom_diario_vta = df_ventas[df_ventas.fecha_liquidacion>=fecha_hace_12_dias].groupby(
    ["cod_compania","cod_sucursal","cod_articulo_magic","fecha_liquidacion"]).cant_cajafisicavta.sum().reset_index().groupby(
    ["cod_compania","cod_sucursal","cod_articulo_magic"]).cant_cajafisicavta.mean().reset_index()
prom_diario_vta["cod_compania"] = (prom_diario_vta["cod_compania"].astype(str).apply(lambda x: str(int(x)).rjust(4, "0")))
prom_diario_vta["cod_sucursal"] = (prom_diario_vta["cod_sucursal"].astype(str).apply(lambda x: str(int(x)).rjust(2, "0")))

# %%
df_stock = pd.merge(prom_diario_vta,stock, on=["cod_compania","cod_sucursal","cod_articulo_magic"],how="left")
df_stock["dias_stock"] = df_stock["stock_cf"]/df_stock["cant_cajafisicavta"]
df_stock =  df_stock[(df_stock.dias_stock > 3) & (df_stock.cant_cajafisicavta > 0)].reset_index(drop=True)

# %%
pan_rec.nunique()
# Out:
# id_cliente            18570
# cod_articulo_magic      124
# dtype: int64

# %%
pan_rec.groupby("id_cliente").cod_articulo_magic.nunique().mean()
# Out:
# 26.812708669897685

# %%
pan_rec.shape
# Out:
# (497912, 2)

# %%
# Cruzamos stock

# %%
test = pd.merge(pan_rec,df_ventas[["id_cliente","cod_compania","cod_sucursal"]].drop_duplicates(),on="id_cliente",how="left")

# %%
test["cod_compania"] = (test["cod_compania"].astype(str).apply(lambda x: str(int(x)).rjust(4, "0")))
test["cod_sucursal"] = (test["cod_sucursal"].astype(str).apply(lambda x: str(int(x)).rjust(2, "0")))

# %%
test_f = pd.merge(test, df_stock, on=["cod_compania","cod_sucursal","cod_articulo_magic"], how="inner")

# %%
test_f.head()
# Out:
#       id_cliente  cod_articulo_magic cod_compania cod_sucursal  \
# 0  EC|0090|10003              515519         0090           17
# 1  EC|0090|10003              515417         0090           17
# 2  EC|0090|10003              515408         0090           17
# 3  EC|0090|10003              508514         0090           17
# 4  EC|0090|10003              599211         0090           17
#
#    cant_cajafisicavta  stock_cf  dias_stock
# 0          267.071429      3699   13.850227
# 1          218.500000      1227    5.615561
# 2          269.770833      1352    5.011661
# 3          685.000000      2297    3.353285
# 4           22.330357       236   10.568573

# %%
test_f.shape
# Out:
# (419733, 7)

# %%
test_f.nunique()
# Out:
# id_cliente            18560
# cod_articulo_magic      120
# cod_compania              1
# cod_sucursal              8
# cant_cajafisicavta      545
# stock_cf                482
# dias_stock              671
# dtype: int64

# %%
PS_VAL_promedio_recs_por_cliente_stock = (
    test_f.groupby("id_cliente")["cod_articulo_magic"].nunique().mean()
)
PS_VAL_promedio_recs_por_cliente_stock
# Out:
# 22.61325431034483

# %%
pan_rec = test_f[["id_cliente","cod_articulo_magic"]].copy()

# %%
pan_rec.to_csv("Output/D_rutas_rec.csv", sep=";", index=False)

# %% [markdown]
# ## 5.-4 Mantener Solo SKUS en especifico (solo usar si se tiene el excel con SKU activos -> el input de ventas ya deberia incluir este filtro)

# %%
# pan_rec=pd.read_csv("Output/D_rutas_rec.csv", sep=";")
# pan_rec["id_cliente"] = "EC|" + pan_rec["id_cliente"]

# %%
# pan_rec.groupby("id_cliente")["cod_articulo_magic"].nunique().mean()

# %%
# pan_rec.groupby("id_cliente")["cod_articulo_magic"].count().mean()

# %%
# sku_con_precio=pd.read_excel("Input/LISTA DE PRECIOS ECUADOR_2024-11-08.xlsx",sheet_name="Hoja1")

# %%
# # Original size de recomendacioness
# pan_rec.shape

# %%
# pan_rec = pan_rec[pan_rec.cod_articulo_magic.isin(sku_con_precio["SKU"].unique())].reset_index(drop=True)

# %%
# # Size de recomendaciones luego de filtar solo a los del excel de SKUs activos
# pan_rec.shape

# %%
# pan_rec.groupby("id_cliente")["cod_articulo_magic"].count().mean()

# %%
# pan_rec["cod_articulo_magic"].nunique()

# %%
# pan_rec.to_csv("Output/D_rutas_rec.csv", sep=";",index=False)

# %% [markdown]
# ## 5.-3 Quitar Recomendaciones de SKUS en especifico

# %%
pan_rec=pd.read_csv("Output/D_rutas_rec.csv", sep=";")
#pan_rec["id_cliente"]="EC|"+pan_rec["id_cliente"]

# %%
skus_sin_precio=[508585,516617,514445,514503,515907,516810,509727,511922,599890]

# %%
pan_rec.shape
# Out:
# (419733, 2)

# %%
pan_rec=pan_rec[~(pan_rec["cod_articulo_magic"].isin(skus_sin_precio))].reset_index(drop=True)

# %%
pan_rec.to_csv("Output/D_rutas_rec.csv", sep=";", index=False)

# %% [markdown]
# ## 5.-2 Quitar Recomendaciones de los ultimos 14 dias

# %%
pan_rec=pd.read_csv("Output/D_rutas_rec.csv", sep=";")

# %%
master_prod=pd.read_csv("Input/EC_maestro_productos.csv")
master_prod
# Out:
#       cod_articulo_magic                                     desc_articulo
# 0                  60968            PREFORMA DE 17.15 GRS CRISTAL  AGUA PT
# 1                  60969           PREFORMA DE 17.15 GRS CRISTAL CON UV PT
# 2                  60970                  PREFORMA DE 17.15 GRS CRISTAL PT
# 3                  60971                     PREFORMA DE 17.15 GRS AZUL PT
# 4                  60972               PREFORMA DE 17.15 GRS AZUL  AGUA PT
# ...                  ...                                               ...
# 7951              524187          CIELO MANZANA PET NO RETORNABLE 600 ML 6
# 7952              624212  CIFRUT NARANJILLA PET NO RETORNABLE 1700 ML 6 MC
# 7953              524212     CIFRUT NARANJILLA PET NO RETORNABLE 1700 ML 6
# 7954              523617      DILYTE FRESA KIWI PET NO RETORNABLE 650 ML 6
# 7955              524582    CIELO AGUA TORONJA PET NO RETORNABLE 600 ML 12
#
# [7956 rows x 2 columns]

# %%
fecha_tomorrow = (
    datetime.now(pytz.timezone("America/Lima")) + timedelta(days=1)
).strftime("%Y-%m-%d")
fecha_tomorrow
# Out:
# '2026-03-31'

# %%
ruta_archivo = f"Output/PS_piloto_v1/D_base_pedidos_{fecha_tomorrow}.csv"
# Verificar si el archivo existe
if os.path.exists(ruta_archivo):
    # Eliminar el archivo si existe
    os.remove(ruta_archivo)
    print(f"El archivo en la ruta {ruta_archivo} ha sido eliminado.")
else:
    print(f"El archivo en la ruta {ruta_archivo} no existe.")
# Out:
# El archivo en la ruta Output/PS_piloto_v1/D_base_pedidos_2026-03-31.csv no existe.

# %%
# Directorio donde se encuentran los archivos
directorio = 'Output/PS_piloto_v1/'

# Expresión regular para encontrar fechas en el nombre de los archivos
patron_fecha = r'\d{4}-\d{2}-\d{2}'

# Lista para almacenar las fechas extraídas
fechas = []

# Iterar sobre los archivos en el directorio
for archivo in os.listdir(directorio):
    # Verificar si el archivo es un archivo CSV y coincide con el patrón de nombres
    if archivo.endswith('.csv') and re.match(r'^D_base_pedidos_\d{4}-\d{2}-\d{2}\.csv$', archivo):
        # Extraer la fecha del nombre del archivo
        fecha = re.search(patron_fecha, archivo).group()
        # Agregar la fecha a la lista
        fechas.append(fecha)

# %%
last_7_days_2=sorted(fechas)[-14:]
#last_7_days_2=last_7_days_2[:-1]
last_7_days_2
# Out:
# ['2026-03-14',
#  '2026-03-16',
#  '2026-03-17',
#  '2026-03-18',
#  '2026-03-19',
#  '2026-03-20',
#  '2026-03-21',
#  '2026-03-23',
#  '2026-03-24',
#  '2026-03-25',
#  '2026-03-26',
#  '2026-03-27',
#  '2026-03-28',
#  '2026-03-30']

# %%
#Leer recomendaciones de los ultimos 7 dias y cruzar con clientes que tienen recomendacion para mañana
last_7_days_recs=pd.DataFrame()
for fecha_rec in last_7_days_2:
    df_temp=pd.read_csv(f"Output/PS_piloto_v1/D_base_pedidos_{fecha_rec}.csv",dtype={"Compania":"str","Cliente":"str"})
    df_temp["id_cliente"]='EC|'+df_temp['Compania']+'|'+df_temp['Cliente']
    df_temp=df_temp[df_temp["id_cliente"].isin(pan_rec["id_cliente"].unique())]
    last_7_days_recs=pd.concat([last_7_days_recs,df_temp],axis=0)
    print(f"{fecha_rec} done")
# Out:
# 2026-03-14 done
# 2026-03-16 done
# 2026-03-17 done
# 2026-03-18 done
# 2026-03-19 done
# 2026-03-20 done
# 2026-03-21 done
# 2026-03-23 done
# 2026-03-24 done
# 2026-03-25 done
# 2026-03-26 done
# 2026-03-27 done
# 2026-03-28 done
# 2026-03-30 done

# %%
# Utilizamos merge para combinar los dataframes, utilizando la columna 'Cliente' como clave
df_combinado = pd.merge(pan_rec, last_7_days_recs, left_on=['id_cliente', 'cod_articulo_magic'],right_on=['id_cliente', 'Producto'], how='left', indicator=True)
# Filtramos los registros que solo están en el DataFrame 1
df_resultado = df_combinado[df_combinado['_merge'] == 'left_only'][["id_cliente","cod_articulo_magic"]].reset_index(drop=True)
df_resultado
# Out:
#            id_cliente  cod_articulo_magic
# 0       EC|0090|10003              515408
# 1       EC|0090|10003              508514
# 2       EC|0090|10003              599211
# 3       EC|0090|10003              515912
# 4       EC|0090|10003              524187
# ...               ...                 ...
# 267437   EC|0090|9999              514411
# 267438   EC|0090|9999              621870
# 267439   EC|0090|9999              623423
# 267440   EC|0090|9999              523106
# 267441   EC|0090|9999              523105
#
# [267442 rows x 2 columns]

# %%
df_resultado.shape
# Out:
# (267442, 2)

# %%
df_resultado.to_csv("Output/D_rutas_rec.csv", sep=";", index=False)

# %% [markdown]
# ##  Quitar Recurrente y Estrategico

# %%
fecha_tomorrow
# Out:
# '2026-03-31'

# %%
pan_rec = pd.read_csv("Output/D_rutas_rec.csv", sep=";")

# %%
pan_rec.head()
# Out:
#       id_cliente  cod_articulo_magic
# 0  EC|0090|10003              515408
# 1  EC|0090|10003              508514
# 2  EC|0090|10003              599211
# 3  EC|0090|10003              515912
# 4  EC|0090|10003              524187

# %%
# pe = pd.read_csv(f"s3://aje-analytics-ps-backup/Pedido_Estrategico/Ecuador/Output/estr_base_pedidos_{fecha_tomorrow}.csv")
pr = pd.read_csv(f"s3://aje-analytics-ps-backup/Pedido_Recurrente/Ecuador/Output/recu_base_pedidos_{fecha_tomorrow}.csv")

# %%
# pe.head()

# %%
pr.head()
# Out:
#   Pais  Compania  Sucursal  Cliente  Modulo  Producto  Cajas  Unidades  \
# 0   EC        90         3   109330      96    508514      1         0
# 1   EC        90         3   109330      96    515408      1         0
# 2   EC        90         3   109330      96    514422      1         0
# 3   EC        90         3   109330      96    515904      1         0
# 4   EC        90         3   109330      96    517260      1         0
#
#         Fecha tipoRecomendacion    ultFecha  Destacar
# 0  2026-03-31               PR1  2026-02-28      True
# 1  2026-03-31               PR2  2026-03-11      True
# 2  2026-03-31               PR3  2026-03-18      True
# 3  2026-03-31               PR4  2026-03-11      True
# 4  2026-03-31               PR5  2026-03-11      True

# %%
# quitar_temp = pd.concat([pe, pr], ignore_index=True).drop_duplicates()
quitar_temp = pr.copy()

# %%
quitar_temp["Compania"] = quitar_temp["Compania"].astype(str).str.zfill(4)
quitar_temp["id_cliente"] = "EC" + '|' + quitar_temp['Compania'] + '|' + quitar_temp['Cliente'].astype(str)
quitar_temp.rename(columns={"Producto":"cod_articulo_magic"},inplace=True)

# %%
quitar_temp
# Out:
#      Pais Compania  Sucursal  Cliente  Modulo  cod_articulo_magic  Cajas  \
# 0      EC     0090         3   109330      96              508514      1
# 1      EC     0090         3   109330      96              515408      1
# 2      EC     0090         3   109330      96              514422      1
# 3      EC     0090         3   109330      96              515904      1
# 4      EC     0090         3   109330      96              517260      1
# ...   ...      ...       ...      ...     ...                 ...    ...
# 9072   EC     0090         3     9766      96              599653      1
# 9073   EC     0090         3     9766      96              524212      1
# 9074   EC     0090         3     9766      96              599479      1
# 9075   EC     0090         3     9766      96              514422      1
# 9076   EC     0090         3     9766      96              515904      1
#
#       Unidades       Fecha tipoRecomendacion    ultFecha  Destacar  \
# 0            0  2026-03-31               PR1  2026-02-28      True
# 1            0  2026-03-31               PR2  2026-03-11      True
# 2            0  2026-03-31               PR3  2026-03-18      True
# 3            0  2026-03-31               PR4  2026-03-11      True
# 4            0  2026-03-31               PR5  2026-03-11      True
# ...        ...         ...               ...         ...       ...
# 9072         0  2026-03-31               PR6  2026-03-14      True
# 9073         0  2026-03-31               PR7  2026-03-07      True
# 9074         0  2026-03-31               PR8  2026-03-14      True
# 9075         0  2026-03-31               PR9  2026-03-28      True
# 9076         0  2026-03-31              PR10  2026-03-07      True
#
#           id_cliente
# 0     EC|0090|109330
# 1     EC|0090|109330
# 2     EC|0090|109330
# 3     EC|0090|109330
# 4     EC|0090|109330
# ...              ...
# 9072    EC|0090|9766
# 9073    EC|0090|9766
# 9074    EC|0090|9766
# 9075    EC|0090|9766
# 9076    EC|0090|9766
#
# [9077 rows x 13 columns]

# %%
pan_rec.shape
# Out:
# (267442, 2)

# %%
# quitamos estrategico y recurrente a nivel cliente
 
# 1. Hacemos un merge por las columnas de coincidencia usando indicator=True
merge_temp = pan_rec.merge(
    quitar_temp[['id_cliente', 'cod_articulo_magic']], 
    on=['id_cliente', 'cod_articulo_magic'], 
    how='left', 
    indicator=True
)

# 2. Nos quedamos solo con las filas que solo existen en pan_rec (left_only)
rec_sin_pe_ni_pr = merge_temp[merge_temp['_merge'] == 'left_only'].drop(columns=['_merge'])

# %%
rec_sin_pe_ni_pr.shape
# Out:
# (261770, 2)

# %%
rec_sin_pe_ni_pr
# Out:
#            id_cliente  cod_articulo_magic
# 0       EC|0090|10003              515408
# 1       EC|0090|10003              508514
# 2       EC|0090|10003              599211
# 3       EC|0090|10003              515912
# 4       EC|0090|10003              524187
# ...               ...                 ...
# 267437   EC|0090|9999              514411
# 267438   EC|0090|9999              621870
# 267439   EC|0090|9999              623423
# 267440   EC|0090|9999              523106
# 267441   EC|0090|9999              523105
#
# [261770 rows x 2 columns]

# %%
rec_sin_pe_ni_pr.to_csv("Output/D_rutas_rec.csv", sep=";", index=False)

# %% [markdown]
# ## 5.0 Calcular Irregularidad de clientes

# %%
pan_rec = pd.read_csv("Output/D_rutas_rec.csv", sep=";")

# %%
pan_rec["id_cliente"].nunique()
# Out:
# 18381

# %%
now = pd.to_datetime(datetime.now(pytz.timezone("America/Lima")).strftime("%Y-%m-01"))
fecha_doce_meses_atras = now - pd.DateOffset(months=12)
lista_m12 = [fecha_doce_meses_atras + pd.DateOffset(months=i) for i in range(12)]
lista_m12

fecha_seis_meses_atras = now - pd.DateOffset(months=6)
lista_m6 = [fecha_seis_meses_atras + pd.DateOffset(months=i) for i in range(6)]
lista_m6
# Out:
# [Timestamp('2025-09-01 00:00:00'),
#  Timestamp('2025-10-01 00:00:00'),
#  Timestamp('2025-11-01 00:00:00'),
#  Timestamp('2025-12-01 00:00:00'),
#  Timestamp('2026-01-01 00:00:00'),
#  Timestamp('2026-02-01 00:00:00')]

# %%
temp_df_ventas = df_ventas[df_ventas["id_cliente"].isin(pan_rec["id_cliente"].unique())]

# %%
qw = (
    temp_df_ventas[["id_cliente", "mes"]]
    .drop_duplicates()
    .sort_values(["id_cliente", "mes"])
    .groupby("id_cliente")
    .tail(12)
    .reset_index(drop=True)
)
qw["mes"] = pd.to_datetime(qw["mes"])
qw["m12"] = qw["mes"].isin(lista_m12)
qw["m6"] = qw["mes"].isin(lista_m6)

# %%
categoria_cliente = qw.groupby("id_cliente")[["m12", "m6"]].sum().reset_index()

# %%
# Definir condiciones
condicion_super = categoria_cliente["m12"] == 12
condicion_frecuente = (
    (categoria_cliente["m12"] < 12)
    & (categoria_cliente["m12"] >= 6)
    & (categoria_cliente["m6"] == 6)
)
condicion_regulares = (categoria_cliente["m6"] <= 6) & (categoria_cliente["m12"] <= 6)
condicion_riesgo = (categoria_cliente["m6"] < 6) & (categoria_cliente["m6"] >= 4)
condicion_irregulares = categoria_cliente["m6"] < 4

# Aplicar condiciones y asignar categorías
categoria_cliente.loc[condicion_super, "categoria_cliente"] = "Super"
categoria_cliente.loc[condicion_frecuente, "categoria_cliente"] = "Frecuente"
categoria_cliente.loc[condicion_regulares, "categoria_cliente"] = "Regular"
categoria_cliente.loc[condicion_riesgo, "categoria_cliente"] = "Riesgo"
categoria_cliente.loc[condicion_irregulares, "categoria_cliente"] = "Irregular"

# %% [markdown]
# **Recalcular Irregularidad**

# %%
# Definir condiciones
condicion_regular = (
    (categoria_cliente["categoria_cliente"] == "Super")
    | (categoria_cliente["categoria_cliente"] == "Frecuente")
    | (categoria_cliente["categoria_cliente"] == "Regular")
    | (categoria_cliente["categoria_cliente"] == "Riesgo")
)
condicion_irregular = categoria_cliente["categoria_cliente"] == "Irregular"
# Aplicar condiciones y asignar categorías
categoria_cliente.loc[condicion_regular, "categoria_cliente_2"] = "Regular"
categoria_cliente.loc[condicion_irregular, "categoria_cliente_2"] = "Irregular"

# %%
categoria_cliente
# Out:
#           id_cliente  m12  m6 categoria_cliente categoria_cliente_2
# 0      EC|0090|10003   11   6         Frecuente             Regular
# 1      EC|0090|10021   11   6         Frecuente             Regular
# 2      EC|0090|10037   11   6         Frecuente             Regular
# 3      EC|0090|10039   11   6         Frecuente             Regular
# 4      EC|0090|10119   11   6         Frecuente             Regular
# ...              ...  ...  ..               ...                 ...
# 18376   EC|0090|9965   11   6         Frecuente             Regular
# 18377   EC|0090|9974   11   6         Frecuente             Regular
# 18378   EC|0090|9976   11   6         Frecuente             Regular
# 18379   EC|0090|9996   11   6         Frecuente             Regular
# 18380   EC|0090|9999   11   6         Frecuente             Regular
#
# [18381 rows x 5 columns]

# %%
categoria_cliente["categoria_cliente"].value_counts(dropna=False)
# Out:
# categoria_cliente
# Frecuente    15515
# Riesgo        1419
# Irregular     1128
# Super          173
# Regular        146
# Name: count, dtype: int64

# %%
categoria_cliente["categoria_cliente_2"].value_counts(dropna=False)
# Out:
# categoria_cliente_2
# Regular      17253
# Irregular     1128
# Name: count, dtype: int64

# %% [markdown]
# ## 5.1. Obteniendo marcas de recomendaciones por cliente

# %%
pan_rec = pd.read_csv("Output/D_rutas_rec.csv", sep=";")

# %%
pan_ventas = df_ventas[(df_ventas["cod_ruta"].isin(rutas))]
pan_ventas2 = df_ventas[(df_ventas["cod_ruta"].isin(low_sku_ruta))]
pan_ventas = pd.concat([pan_ventas, pan_ventas2], axis=0)

# %%
marca_articulo = pan_ventas[["desc_categoria", "cod_articulo_magic"]].drop_duplicates()
print(marca_articulo.shape)
marca_articulo.head()
# Out:
# (159, 2)
#   desc_categoria  cod_articulo_magic
# 0       GASEOSAS              599653
# 1         CITRUS              509728
# 2           AGUA              508514
# 3       GASEOSAS              523079
# 4         CITRUS              511920

# %%
cliente_rec_marca = pd.merge(
    pan_rec, marca_articulo, on="cod_articulo_magic", how="left"
)
cliente_rec_marca["desc_categoria"] = cliente_rec_marca["desc_categoria"].str.strip()
print(cliente_rec_marca.shape)
cliente_rec_marca
# Out:
# (261770, 3)
#            id_cliente  cod_articulo_magic       desc_categoria
# 0       EC|0090|10003              515408   BEBIDAS DEPORTIVAS
# 1       EC|0090|10003              508514                 AGUA
# 2       EC|0090|10003              599211  CONSERVA DE PESCADO
# 3       EC|0090|10003              515912   BEBIDAS DEPORTIVAS
# 4       EC|0090|10003              524187                 AGUA
# ...               ...                 ...                  ...
# 261765   EC|0090|9999              514411               NECTAR
# 261766   EC|0090|9999              621870                 CAFE
# 261767   EC|0090|9999              623423           DETERGENTE
# 261768   EC|0090|9999              523106             GASEOSAS
# 261769   EC|0090|9999              523105             GASEOSAS
#
# [261770 rows x 3 columns]

# %% [markdown]
# ## 5.2. Calcular marcas distintas recomendadas por cliente

# %%
cods2 = cliente_rec_marca.groupby("id_cliente")["desc_categoria"].nunique().reset_index()
print(cods2.shape)
cods2.head()
# Out:
# (18381, 2)
#       id_cliente  desc_categoria
# 0  EC|0090|10003               9
# 1  EC|0090|10021              11
# 2  EC|0090|10037               7
# 3  EC|0090|10039               9
# 4  EC|0090|10119              12

# %% [markdown]
# ## 5.3 Quitando los SKUs de las ultimas 2 semanas (Evitar recompra)

# %%
last_2_weeks = pd.to_datetime(datetime.now(pytz.timezone("America/Lima"))) - pd.DateOffset(
    days=14
)
last_2_weeks
# Out:
# Timestamp('2026-03-16 15:48:22.905655-0500', tz='America/Lima')

# %%
# Asegurarse de que 'fecha_liquidacion' esté en formato datetime
pan_ventas["fecha_liquidacion"] = pd.to_datetime(pan_ventas["fecha_liquidacion"])
# Convertir 'fecha_liquidacion' a la misma zona horaria que 'last_year'
pan_ventas["fecha_liquidacion"] = pan_ventas["fecha_liquidacion"].dt.tz_localize(
    "America/Lima", nonexistent="NaT", ambiguous="NaT"
)

# %%
df_quitar_2_weeks = pan_ventas[pan_ventas["fecha_liquidacion"]>=last_2_weeks][["id_cliente","cod_articulo_magic"]].drop_duplicates().reset_index(drop=True)

# %%
# Hacemos un merge para identificar coincidencias
cliente_rec_sin4 = cliente_rec_marca.merge(df_quitar_2_weeks, on=['id_cliente', 'cod_articulo_magic'], how='left', indicator=True)
# Filtramos solo los registros que NO están en df_quitar_2_weeks
cliente_rec_sin4 = cliente_rec_sin4[cliente_rec_sin4['_merge'] == 'left_only'].drop(columns=['_merge'])

# %%
cliente_rec_marca.id_cliente.nunique()
# Out:
# 18381

# %%
cliente_rec_sin4.id_cliente.nunique()
# Out:
# 18092

# %%
cliente_rec_sin4
# Out:
#            id_cliente  cod_articulo_magic       desc_categoria
# 0       EC|0090|10003              515408   BEBIDAS DEPORTIVAS
# 2       EC|0090|10003              599211  CONSERVA DE PESCADO
# 3       EC|0090|10003              515912   BEBIDAS DEPORTIVAS
# 4       EC|0090|10003              524187                 AGUA
# 5       EC|0090|10003              524189                 AGUA
# ...               ...                 ...                  ...
# 261764   EC|0090|9999              511920               CITRUS
# 261766   EC|0090|9999              621870                 CAFE
# 261767   EC|0090|9999              623423           DETERGENTE
# 261768   EC|0090|9999              523106             GASEOSAS
# 261769   EC|0090|9999              523105             GASEOSAS
#
# [188599 rows x 3 columns]

# %% [markdown]
# ## 5.4 Filtro para calcula antiguedad de clientes

# %%
pan_ventas = pan_ventas.rename(columns={"fecha_creacion_cliente": "fecha_creacion"})

# %%
# Convertir la columna 'fecha_creacion' a tipo fecha
pan_ventas["fecha_creacion"] = pd.to_datetime(
    pan_ventas["fecha_creacion"], format="%Y%m%d"
)

# %%
# Definir una función para etiquetar los clientes según su fecha de creación
def etiquetar_cliente(fecha_creacion):
    if pd.isnull(fecha_creacion):
        return (
            "nf"  # Si la fecha de creación es nula, etiquetar como 'nf' (no encontrada)
        )
    else:
        hoy = datetime.now()  # Obtener la fecha actual
        hace_12_meses = hoy - timedelta(days=365)  # Calcular hace 12 meses
        if fecha_creacion >= hace_12_meses:
            return "new_client"  # Si la fecha de creación está dentro de los últimos 12 meses, etiquetar como 'new_client'
        else:
            return "old_client"  # Si la fecha de creación es anterior a los últimos 12 meses, etiquetar como 'old_client'

# %%
# Aplicar la función a la columna 'fecha_creacion' para crear la nueva columna 'tipo_cliente'
pan_ventas["antiguedad"] = pan_ventas["fecha_creacion"].apply(etiquetar_cliente)

# %%
pan_antiguedad_clientes = (
    pan_ventas[["id_cliente", "fecha_creacion", "antiguedad"]]
    .drop_duplicates()
    .reset_index(drop=True)
)

# %% [markdown]
# ## 5.4.2 Obteniendo datos necesarios para armar DF para subir a SalesForce

# %%
# pan_ventas.groupby(["id_cliente","cod_compania","cod_sucursal","cod_cliente","cod_modulo"])[["cant_cajafisicavta","cant_cajaunitvta"]].sum().reset_index()

# %%
datos_para_salesforce = (
    pan_ventas.groupby(
        ["id_cliente", "cod_compania", "cod_sucursal", "cod_cliente", "cod_ruta"]
    )[
        [
            "id_cliente",
            "cod_compania",
            "cod_sucursal",
            "cod_cliente",
            "cod_modulo",
            "cod_ruta",
        ]
    ]
    .head(1)
    .reset_index(drop=True)
)

# %%
datos_para_salesforce["cod_cliente"]=datos_para_salesforce["cod_cliente"].astype(int)
datos_para_salesforce["cod_sucursal"]=datos_para_salesforce["cod_sucursal"].astype(int)
datos_para_salesforce["cod_compania"]=datos_para_salesforce["cod_compania"].astype(int)
datos_para_salesforce["cod_modulo"]=datos_para_salesforce["cod_modulo"].astype(int)
datos_para_salesforce["cod_ruta"]=datos_para_salesforce["cod_ruta"].astype(int)

# %% [markdown]
# ## 5.5 Juntando las Recomendaciones Finales
#  - Ordenado de acuerdo al peso de la recomendación y el id de usuario.
#  - Hay 5 skus de 5 marcas distintas que se recomiendan a cada usuario
#  - Ningún SKU que haya comprado el usuario en sus ultimas X visitas será recomendado. La cantidad de visitas (X) a ignorar depende de sus visitas promedio mensuales.

# %%
# Obtener primer SKU de cada marca de la recomendacion
final_rec = cliente_rec_sin4.groupby(["id_cliente", "desc_categoria"]).first().reset_index()
# Agregar Marca de sus primeras compras
final_rec = pd.merge(final_rec, cods2, how="left", on="id_cliente")
# Agregar descripcion de SKU recomendado
pan_prod = pan_prod[["cod_articulo_magic", "desc_articulo"]].drop_duplicates()
pan_prod = pan_prod.groupby(["cod_articulo_magic"]).first().reset_index()
final_rec = pd.merge(final_rec, pan_prod, how="left", on="cod_articulo_magic")
# Cambiar nombre de columnas
final_rec.columns = ["id_cliente", "marca_rec", "sku", "len_marca_rec", "desc_rec"]
# Agregar Giro del cliente
giros = df_ventas[df_ventas["id_cliente"].isin(final_rec["id_cliente"].unique())][
    ["id_cliente", "desc_giro", "desc_subgiro"]
].drop_duplicates()
final_rec = pd.merge(final_rec, giros, on="id_cliente", how="left")
# Agregar si el cliente es Regular o Irregular
final_rec = pd.merge(
    final_rec,
    categoria_cliente[["id_cliente", "categoria_cliente_2"]],
    on="id_cliente",
    how="left",
)
final_rec.loc[final_rec["categoria_cliente_2"] == "Irregular", "desc_giro"] = np.nan
# Agregar antiguedad de cliente
final_rec = pd.merge(final_rec, pan_antiguedad_clientes, how="left", on="id_cliente")
# Agregar segmento de cliente
info_segmentos = pan_ventas[
    [
        "id_cliente",
        "new_segment",
        "dias_de_visita__c",
        "periodo_de_visita__c",
        "ultima_visita",
    ]
].drop_duplicates()
info_segmentos = info_segmentos.groupby(["id_cliente"]).first().reset_index()
final_rec = pd.merge(final_rec, info_segmentos, how="left", on="id_cliente")
# Agregar datos necesarios para SALESFORCE
final_rec = pd.merge(final_rec, datos_para_salesforce, how="left", on="id_cliente")
# Agregar Peso de marcas dependiendo del giro del cliente
final_rec["peso"] = final_rec.apply(
    lambda row: mapeo_diccionario.get(row["desc_subgiro"], {}).get(row["marca_rec"], 5),
    axis=1,
)

# %%
# Ordenar la recomendacion de acuerdo al peso de la marca y nos quedamos con las 5 primeras marcas
final_rec = (
    final_rec.sort_values(["id_cliente", "peso"]).groupby(["id_cliente"]).head(5)
)
# Agregamos rank de la marca recomendada
final_rec["marca_rec_rank"] = final_rec.groupby("id_cliente").cumcount() + 1
final_rec = final_rec.reset_index(drop=True)

# %%
final_rec["sku"] = final_rec["sku"].astype(int)
final_rec["peso"] = final_rec["peso"].astype(int)
final_rec["marca_rec_rank"] = final_rec["marca_rec_rank"].astype(int)

# %%
final_rec
# Out:
#           id_cliente            marca_rec     sku  len_marca_rec  \
# 0      EC|0090|10003   BEBIDAS DEPORTIVAS  515408              9
# 1      EC|0090|10003             GASEOSAS  523108              9
# 2      EC|0090|10003                 AGUA  524187              9
# 3      EC|0090|10003               NECTAR  514411              9
# 4      EC|0090|10003           DETERGENTE  623423              9
# ...              ...                  ...     ...            ...
# 76933   EC|0090|9999             GASEOSAS  500010              8
# 76934   EC|0090|9999               CITRUS  511920              8
# 76935   EC|0090|9999           DETERGENTE  623423              8
# 76936   EC|0090|9999                 CAFE  621870              8
# 76937   EC|0090|9999  CONSERVA DE PESCADO  599211              8
#
#                                                 desc_rec  \
# 0                SPORADE UVA PET NO RETORNABLE 500 ML 12
# 1       BIG LIMON SIN AZUCAR PET NO RETORNABLE 300 ML 24
# 2               CIELO MANZANA PET NO RETORNABLE 600 ML 6
# 3                  PULP DURAZNO TETRA PAK 250 ml 24 pack
# 4            DESS DETERGENTE POLVO LIMON FUNDA 500 GRS 6
# ...                                                  ...
# 76933               BIG COLA PET NO RETORNABLE 300 ML 24
# 76934  CIFRUT NARANJA, MANDARINA Y LIMON PET NO RETOR...
# 76935        DESS DETERGENTE POLVO LIMON FUNDA 500 GRS 6
# 76936         D GUSSTO CAFE LIOFILIZADO STICK 6 ML 12 MC
# 76937  D GUSSTO ATUN EN TROZOS CON ACEITE DE SOYA LAT...
#
#                    desc_giro      desc_subgiro categoria_cliente_2  \
# 0      BODEGA Y PARTICULARES  BODEGAS, TIENDAS             Regular
# 1      BODEGA Y PARTICULARES  BODEGAS, TIENDAS             Regular
# 2      BODEGA Y PARTICULARES  BODEGAS, TIENDAS             Regular
# 3      BODEGA Y PARTICULARES  BODEGAS, TIENDAS             Regular
# 4      BODEGA Y PARTICULARES  BODEGAS, TIENDAS             Regular
# ...                      ...               ...                 ...
# 76933  BODEGA Y PARTICULARES  BODEGAS, TIENDAS             Regular
# 76934  BODEGA Y PARTICULARES  BODEGAS, TIENDAS             Regular
# 76935  BODEGA Y PARTICULARES  BODEGAS, TIENDAS             Regular
# 76936  BODEGA Y PARTICULARES  BODEGAS, TIENDAS             Regular
# 76937  BODEGA Y PARTICULARES  BODEGAS, TIENDAS             Regular
#
#       fecha_creacion antiguedad  ... dias_de_visita__c periodo_de_visita__c  \
# 0                NaT         nf  ...               2;5                   F1
# 1                NaT         nf  ...               2;5                   F1
# 2                NaT         nf  ...               2;5                   F1
# 3                NaT         nf  ...               2;5                   F1
# 4                NaT         nf  ...               2;5                   F1
# ...              ...        ...  ...               ...                  ...
# 76933            NaT         nf  ...               2;5                   F1
# 76934            NaT         nf  ...               2;5                   F1
# 76935            NaT         nf  ...               2;5                   F1
# 76936            NaT         nf  ...               2;5                   F1
# 76937            NaT         nf  ...               2;5                   F1
#
#       ultima_visita cod_compania  cod_sucursal  cod_cliente  cod_modulo  \
# 0        2026-03-27           90            17        10003         246
# 1        2026-03-27           90            17        10003         246
# 2        2026-03-27           90            17        10003         246
# 3        2026-03-27           90            17        10003         246
# 4        2026-03-27           90            17        10003         246
# ...             ...          ...           ...          ...         ...
# 76933    2026-03-27           90            17         9999         246
# 76934    2026-03-27           90            17         9999         246
# 76935    2026-03-27           90            17         9999         246
# 76936    2026-03-27           90            17         9999         246
# 76937    2026-03-27           90            17         9999         246
#
#        cod_ruta  peso  marca_rec_rank
# 0          4917     1               1
# 1          4917     1               2
# 2          4917     2               3
# 3          4917     2               4
# 4          4917     9               5
# ...         ...   ...             ...
# 76933      4917     1               1
# 76934      4917     3               2
# 76935      4917     9               3
# 76936      4917    10               4
# 76937      4917    12               5
#
# [76938 rows x 21 columns]

# %% [markdown]
# ## 5.7 Filtro de Recomendaciones por Segmento de cliente

# %%
# Definir una función para filtrar las filas según el valor de 'new_segment'
def filtrar_segmento(group):
    segmento = group["new_segment"].iloc[
        0
    ]  # Obtener el valor del segmento para el grupo
    if segmento == "BLINDAR":
        return group.head(1)  # Si el segmento es 'Blindar', mantener la primera fila
    elif segmento == "MANTENER":
        return group.head(
            2
        )  # Si el segmento es 'Mantener', mantener las dos primeras filas
    elif segmento == "DESARROLLAR":
        return group.head(
            3
        )  # Si el segmento es 'Desarrollar', mantener las tres primeras filas
    elif segmento == "OPTIMIZAR":
        return group.head(
            4
        )  # Si el segmento es 'Optimizar', mantener las cuatro primeras filas
    else:
        return group  # Si el segmento no es ninguno de los especificados, mantener todas las filas

# %%
final_rec = (
    final_rec.groupby("id_cliente").apply(filtrar_segmento).reset_index(drop=True)
)
# Out:
# /tmp/ipykernel_31118/3325175710.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   final_rec.groupby("id_cliente").apply(filtrar_segmento).reset_index(drop=True)

# %%
final_rec.groupby("new_segment")["id_cliente"].nunique()
# Out:
# new_segment
# BLINDAR        2850
# DESARROLLAR    4981
# MANTENER       6235
# OPTIMIZAR      4026
# Name: id_cliente, dtype: int64

# %%
final_rec.groupby(["new_segment","id_cliente"]).sku.nunique().groupby("new_segment").mean()
# Out:
# new_segment
# BLINDAR        1.000000
# DESARROLLAR    2.869303
# MANTENER       1.956215
# OPTIMIZAR      3.119722
# Name: sku, dtype: float64

# %% [markdown]
# ## 5.8. Guardando recomendacion para D&A y Comercial

# %%
final_rec.id_cliente.nunique()
# Out:
# 18092

# %%
final_rec.dias_de_visita__c.value_counts(dropna=False)
# Out:
# dias_de_visita__c
# 2;5              41110
# 2                  788
# 1;2;3;4;5;6;7        1
# Name: count, dtype: int64

# %%
final_rec.periodo_de_visita__c.value_counts(dropna=False)
# Out:
# periodo_de_visita__c
# F1    41899
# Name: count, dtype: int64

# %%
final_rec.ultima_visita.value_counts(dropna=False)
# Out:
# ultima_visita
# 2026-03-27    40573
# 2026-03-24      747
# 2026-03-20       66
# 2026-03-17       61
# 2026-03-13       61
# 2026-01-13       55
# 2026-01-20       42
# 2026-02-24       40
# 2026-03-06       36
# 2026-03-10       35
# 2026-01-23       27
# 2026-01-30       21
# 2026-03-03       20
# 2026-01-16       19
# 2026-01-09       16
# 2026-02-20       15
# 2026-02-06       14
# 2026-02-03       13
# 2026-02-13       11
# 2026-02-10        8
# 2026-02-17        4
# 2026-02-27        3
# 2026-01-02        3
# 2026-01-27        3
# 2026-01-06        3
# 2026-03-23        2
# 2026-03-28        1
# Name: count, dtype: int64

# %% [markdown]
# ### 5.8.1 Para D&A

# %%
fecha_tomorrow = (
    datetime.now(pytz.timezone("America/Lima")) + timedelta(days=1)
).strftime("%Y-%m-%d")
fecha_tomorrow
# Out:
# '2026-03-31'

# %%
final_rec.to_csv(
    f"Output/PS_piloto_data_v1/D_pan_recs_data_{fecha_tomorrow}.csv", index=False
)

# %%
# Establecer la conexión con S3
bucket_name = 'aje-analytics-ps-backup'  # nombre de bucket en S3
file_name = f'PS_Ecuador/Output/PS_piloto_data_v1/D_pan_recs_data_{fecha_tomorrow}.csv'  # nombre para el archivo en S3
s3_path = f's3://{bucket_name}/{file_name}'

# Escribir el dataframe en S3 con AWS Data Wrangler
wr.s3.to_csv(final_rec, s3_path, index=False)
# Out:
# {'paths': ['s3://aje-analytics-ps-backup/PS_Ecuador/Output/PS_piloto_data_v1/D_pan_recs_data_2026-03-31.csv'],
#  'partitions_values': {}}

# %% [markdown]
# ### 5.8.2 Para subir a PS

# %%
recomendaciones_para_salesforce = final_rec[
    ["cod_compania", "cod_sucursal", "cod_cliente", "cod_modulo", "sku"]
]
recomendaciones_para_salesforce["Pais"] = "EC"
recomendaciones_para_salesforce["Cajas"] = int(1)
recomendaciones_para_salesforce["Unidades"] = int(0)
recomendaciones_para_salesforce["Fecha"] = fecha_tomorrow
recomendaciones_para_salesforce = recomendaciones_para_salesforce[
    [
        "Pais",
        "cod_compania",
        "cod_sucursal",
        "cod_cliente",
        "cod_modulo",
        "sku",
        "Cajas",
        "Unidades",
        "Fecha",
    ]
]
recomendaciones_para_salesforce.columns = [
    "Pais",
    "Compania",
    "Sucursal",
    "Cliente",
    "Modulo",
    "Producto",
    "Cajas",
    "Unidades",
    "Fecha",
]
# Out:
# /tmp/ipykernel_31118/4041848949.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recomendaciones_para_salesforce["Pais"] = "EC"
# /tmp/ipykernel_31118/4041848949.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recomendaciones_para_salesforce["Cajas"] = int(1)
# /tmp/ipykernel_31118/4041848949.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recomendaciones_para_salesforce["Unidades"] = int(0)
# /tmp/ipykernel_31118/4041848949.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recomendaciones_para_salesforce["Fecha"] = fecha_tomorrow

# %%
recomendaciones_para_salesforce["Compania"] = recomendaciones_para_salesforce[
    "Compania"
].apply(lambda x: str(int(x)).rjust(4, "0"))
recomendaciones_para_salesforce["Sucursal"] = recomendaciones_para_salesforce[
    "Sucursal"
].apply(lambda x: str(int(x)).rjust(2, "0"))

# %%
recomendaciones_para_salesforce.Sucursal.unique()
# Out:
# array(['17', '11', '04', '03', '07', '06', '08', '09'], dtype=object)

# %%
recomendaciones_para_salesforce.Compania.unique()
# Out:
# array(['0090'], dtype=object)

# %%
recomendaciones_para_salesforce.Cliente.nunique()
# Out:
# 18092

# %%
recomendaciones_para_salesforce
# Out:
#       Pais Compania Sucursal  Cliente  Modulo  Producto  Cajas  Unidades  \
# 0       EC     0090       17    10003     246    515408      1         0
# 1       EC     0090       17    10003     246    523108      1         0
# 2       EC     0090       17    10021     246    515417      1         0
# 3       EC     0090       17    10037     195    515519      1         0
# 4       EC     0090       17    10037     195    524189      1         0
# ...    ...      ...      ...      ...     ...       ...    ...       ...
# 41894   EC     0090       17     9996     246    621870      1         0
# 41895   EC     0090       17     9996     246    623423      1         0
# 41896   EC     0090       17     9999     246    500010      1         0
# 41897   EC     0090       17     9999     246    511920      1         0
# 41898   EC     0090       17     9999     246    623423      1         0
#
#             Fecha
# 0      2026-03-31
# 1      2026-03-31
# 2      2026-03-31
# 3      2026-03-31
# 4      2026-03-31
# ...           ...
# 41894  2026-03-31
# 41895  2026-03-31
# 41896  2026-03-31
# 41897  2026-03-31
# 41898  2026-03-31
#
# [41899 rows x 9 columns]

# %%
recomendaciones_para_salesforce.Cliente.nunique()
# Out:
# 18092

# %%
rutas_cliente = df_ventas[["cod_cliente", "cod_ruta"]].drop_duplicates()

# %% [markdown]
# **Conteo de marcas recomendadas**

# %%
# count = (
#     final_rec.groupby("id_cliente")["marca_rec"]
#     .apply(lambda x: "-".join((x)))
#     .reset_index(name="marcas_ordenadas")
# )
# count = (
#     count.groupby("marcas_ordenadas")["id_cliente"]
#     .nunique()
#     .sort_values(ascending=False)
# )
# count

# %% [markdown]
# **Conteo de SKUs recomendadas**

# %%
# count2 = (
#     final_rec.groupby("id_cliente")["sku"]
#     .apply(lambda x: "-".join(x.astype(str)))
#     .reset_index(name="marcas_ordenadas")
# )
# count2 = (
#     count2.groupby("marcas_ordenadas")["id_cliente"]
#     .nunique()
#     .sort_values(ascending=False)
#     .reset_index()
# )
# count2["f"] = count2["id_cliente"] / count2["id_cliente"].sum()
# count2["fa"] = count2["f"].cumsum()
# count2

# %%
# print(f"RESUMEN para {fecha_tomorrow}")
# print(
#     "Total de clientes a recomendar: ",
#     recomendaciones_para_salesforce.Cliente.nunique(),
# )
# print("Combinaciones de recomendaciones de MARCAS:", count.shape[0])
# print("Marcar recomendadas:", final_rec.marca_rec.unique())
# print("Combinaciones de recomendaciones de SKUs:", count2.shape[0])
# print(
#     "Combinaciones de recomendaciones de SKUs al 80% de clientes:",
#     count2[count2["fa"] <= 0.8].shape[0],
# )
# print("SKUs usados en la recomendacion:", final_rec["sku"].nunique())

# %%
recomendaciones_para_salesforce
# Out:
#       Pais Compania Sucursal  Cliente  Modulo  Producto  Cajas  Unidades  \
# 0       EC     0090       17    10003     246    515408      1         0
# 1       EC     0090       17    10003     246    523108      1         0
# 2       EC     0090       17    10021     246    515417      1         0
# 3       EC     0090       17    10037     195    515519      1         0
# 4       EC     0090       17    10037     195    524189      1         0
# ...    ...      ...      ...      ...     ...       ...    ...       ...
# 41894   EC     0090       17     9996     246    621870      1         0
# 41895   EC     0090       17     9996     246    623423      1         0
# 41896   EC     0090       17     9999     246    500010      1         0
# 41897   EC     0090       17     9999     246    511920      1         0
# 41898   EC     0090       17     9999     246    623423      1         0
#
#             Fecha
# 0      2026-03-31
# 1      2026-03-31
# 2      2026-03-31
# 3      2026-03-31
# 4      2026-03-31
# ...           ...
# 41894  2026-03-31
# 41895  2026-03-31
# 41896  2026-03-31
# 41897  2026-03-31
# 41898  2026-03-31
#
# [41899 rows x 9 columns]

# %%
recomendaciones_para_salesforce.groupby("Cliente")["Producto"].nunique().mean()
# Out:
# 2.315885474242759

# %%
asd = (
    recomendaciones_para_salesforce.groupby("Cliente")
    .agg({"Producto": ["count", "nunique"]})
    .reset_index()
)
asd.columns = ["Cliente", "count", "nunique"]
asd["dif"] = asd["count"] == asd["nunique"]
asd.sort_values(["dif", "count"])
# Out:
#        Cliente  count  nunique   dif
# 0         1953      1        1  True
# 5         2112      1        1  True
# 8         2130      1        1  True
# 10        2172      1        1  True
# 18        2848      1        1  True
# ...        ...    ...      ...   ...
# 16601   480742      4        4  True
# 17226   483337      4        4  True
# 17284   483538      4        4  True
# 17437   484252      4        4  True
# 17850   486168      4        4  True
#
# [18092 rows x 4 columns]

# %%
asd.dif.value_counts()
# Out:
# dif
# True    18092
# Name: count, dtype: int64

# %%
recomendaciones_para_salesforce.to_csv(
    f"Output/PS_piloto_v1/D_base_pedidos_{fecha_tomorrow}.csv", index=False
)

# %%
# Establecer la conexión con S3
bucket_name = 'aje-analytics-ps-backup'  # nombre de bucket en S3
file_name = f'PS_Ecuador/Output/PS_piloto_v1/D_base_pedidos_{fecha_tomorrow}.csv'  # nombre para el archivo en S3
s3_path = f's3://{bucket_name}/{file_name}'

# Escribir el dataframe en S3 con AWS Data Wrangler
wr.s3.to_csv(recomendaciones_para_salesforce, s3_path, index=False)
# Out:
# {'paths': ['s3://aje-analytics-ps-backup/PS_Ecuador/Output/PS_piloto_v1/D_base_pedidos_2026-03-31.csv'],
#  'partitions_values': {}}

# %%
recomendaciones_para_salesforce.shape
# Out:
# (41899, 9)

# %%
pan_ventas.cod_compania=pan_ventas.cod_compania.astype(int)

# %%
pan_ventas["cod_compania"] = (
    pan_ventas["cod_compania"].astype(str).apply(lambda x: str(int(x)).rjust(4, "0"))
)

# %%
recomendaciones_para_salesforce.dtypes
# Out:
# Pais        object
# Compania    object
# Sucursal    object
# Cliente      int64
# Modulo       int64
# Producto     int64
# Cajas        int64
# Unidades     int64
# Fecha       object
# dtype: object

# %%
pan_ventas["cod_cliente"] = pan_ventas["cod_cliente"].astype(int)

# %%
val = pd.merge(recomendaciones_para_salesforce,pan_prod,left_on="Producto",right_on="cod_articulo_magic",how="left")
val = pd.merge(val,pan_ventas[["cod_compania","cod_cliente","cod_ruta","desc_sucursal","fecha_proceso"]].drop_duplicates(),left_on=["Compania","Cliente"],right_on=["cod_compania","cod_cliente"],how="left")

# %%
val.cod_cliente = val.cod_cliente.astype(int)
val.cod_ruta = val.cod_ruta.astype(int)
val.fecha_proceso = val.fecha_proceso.astype(int)

# %%
val
# Out:
#       Pais Compania Sucursal  Cliente  Modulo  Producto  Cajas  Unidades  \
# 0       EC     0090       17    10003     246    515408      1         0
# 1       EC     0090       17    10003     246    523108      1         0
# 2       EC     0090       17    10021     246    515417      1         0
# 3       EC     0090       17    10037     195    515519      1         0
# 4       EC     0090       17    10037     195    524189      1         0
# ...    ...      ...      ...      ...     ...       ...    ...       ...
# 41895   EC     0090       17     9996     246    621870      1         0
# 41896   EC     0090       17     9996     246    623423      1         0
# 41897   EC     0090       17     9999     246    500010      1         0
# 41898   EC     0090       17     9999     246    511920      1         0
# 41899   EC     0090       17     9999     246    623423      1         0
#
#             Fecha  cod_articulo_magic  \
# 0      2026-03-31              515408
# 1      2026-03-31              523108
# 2      2026-03-31              515417
# 3      2026-03-31              515519
# 4      2026-03-31              524189
# ...           ...                 ...
# 41895  2026-03-31              621870
# 41896  2026-03-31              623423
# 41897  2026-03-31              500010
# 41898  2026-03-31              511920
# 41899  2026-03-31              623423
#
#                                            desc_articulo cod_compania  \
# 0                SPORADE UVA PET NO RETORNABLE 500 ML 12         0090
# 1       BIG LIMON SIN AZUCAR PET NO RETORNABLE 300 ML 24         0090
# 2                SPORADE UVA PET NO RETORNABLE 1200 ML 6         0090
# 3      SPORADE FRUTAS TROPICALES PET NO RETORNABLE 12...         0090
# 4              CIELO LIMONADA PET NO RETORNABLE 600 ML 6         0090
# ...                                                  ...          ...
# 41895         D GUSSTO CAFE LIOFILIZADO STICK 6 ML 12 MC         0090
# 41896        DESS DETERGENTE POLVO LIMON FUNDA 500 GRS 6         0090
# 41897               BIG COLA PET NO RETORNABLE 300 ML 24         0090
# 41898  CIFRUT NARANJA, MANDARINA Y LIMON PET NO RETOR...         0090
# 41899        DESS DETERGENTE POLVO LIMON FUNDA 500 GRS 6         0090
#
#        cod_cliente  cod_ruta        desc_sucursal  fecha_proceso
# 0            10003      4917  CEDIS GUAYAQUIL SUR       20260330
# 1            10003      4917  CEDIS GUAYAQUIL SUR       20260330
# 2            10021      4917  CEDIS GUAYAQUIL SUR       20260330
# 3            10037      3117  CEDIS GUAYAQUIL SUR       20260330
# 4            10037      3117  CEDIS GUAYAQUIL SUR       20260330
# ...            ...       ...                  ...            ...
# 41895         9996      4917  CEDIS GUAYAQUIL SUR       20260330
# 41896         9996      4917  CEDIS GUAYAQUIL SUR       20260330
# 41897         9999      4917  CEDIS GUAYAQUIL SUR       20260330
# 41898         9999      4917  CEDIS GUAYAQUIL SUR       20260330
# 41899         9999      4917  CEDIS GUAYAQUIL SUR       20260330
#
# [41900 rows x 16 columns]

# %%
fecha_hoy_val = (
    datetime.now(pytz.timezone("America/Lima")) + timedelta(days=0)
).strftime("%Y-%m-%d")
fecha_hoy_val
# Out:
# '2026-03-30'

# %%
# val.to_csv(f"Val_comercial/D_EC_validacion_recomendaciones_{fecha_hoy_val}.csv",index=False)

# %%
# # Detener el monitoreo
# running = False
# monitor_thread.join()

# # Graficar consumo de RAM y CPU
# fig, ax1 = plt.subplots(figsize=(10, 5))

# ax1.set_xlabel("Tiempo (segundos)")
# ax1.set_ylabel("RAM usada (GB)", color="tab:blue")
# ax1.plot(timestamps, mem_usage_gb, marker="o", linestyle="-", color="tab:blue", label="RAM (GB)")
# ax1.tick_params(axis="y", labelcolor="tab:blue")

# ax2 = ax1.twinx()  # Crear segundo eje Y para CPU
# ax2.set_ylabel("CPU usada (%)", color="tab:red")
# ax2.plot(timestamps, cpu_usage_percent, marker="x", linestyle="--", color="tab:red", label="CPU (%)")
# ax2.tick_params(axis="y", labelcolor="tab:red")

# fig.suptitle("Consumo de CPU y RAM del Notebook")
# ax1.grid()
# fig.tight_layout()
# plt.show()

# %%
# Apaga el Kernel para luego poder usar los demás notebooks sin llenar la memoria
import IPython
app = IPython.get_ipython()
app.kernel.do_shutdown(False)  # True indica apagar completamente el kernel
# Out:
# {'status': 'ok', 'restart': False}
